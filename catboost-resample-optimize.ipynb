# %%
from pathlib import Path
import optuna
from fastai.tabular.core import cont_cat_split
import pandas as pd
from sklearn import compose, impute, pipeline, preprocessing, model_selection
import numpy as np
from sklearn import metrics
from catboost import CatBoostClassifier

path = Path("./data")
output_path = Path("./output")

# %%
import warnings
# ignore UserWarning
warnings.filterwarnings("ignore", category=UserWarning)

# %%
def balanced_log_loss(y_true, y_pred):
    nc = np.bincount(y_true)
    return metrics.log_loss(y_true, y_pred, sample_weight=1 / nc[y_true], eps=1e-15)


class BalancedLogLossMetric:
    def get_final_error(self, error, weight):
        return error / weight

    def is_max_optimal(self):
        return False

    def evaluate(self, approxes, target, weight):
        y_true = np.array(target).astype(int)
        y_pred = np.array(approxes[0])
        nc = np.bincount(y_true)
        balanced_logloss = metrics.log_loss(y_true, y_pred, sample_weight=1 / nc[y_true], eps=1e-15)
        return balanced_logloss, 1.0

# %%
def get_tree_preprocess_pipeline():
    return pipeline.make_pipeline(
        impute.KNNImputer(n_neighbors=10, weights="distance"),
    ).set_output(transform="pandas")


# Load data

df = pd.read_csv(path / "train.csv", index_col="Id")
dep_vars = ["Class"]

drop_vars = ["EJ"]
df.drop(columns=drop_vars, inplace=True)

train_df, test_df = model_selection.train_test_split(df, test_size=0.4, stratify=df[dep_vars], random_state=33)

preprocessor = get_tree_preprocess_pipeline()

# Preprocess training data
X_pre = preprocessor.fit_transform(train_df.drop(columns=dep_vars))
train_df = pd.merge(X_pre, train_df[dep_vars], left_index=True, right_index=True)
X = train_df.drop(columns=dep_vars, errors="ignore")
y = train_df[dep_vars]

# Preprocess test data
X_test_pre = preprocessor.transform(test_df.drop(columns=dep_vars))
test_df = pd.merge(X_test_pre, test_df[dep_vars], left_index=True, right_index=True)
X_test = test_df.drop(columns=dep_vars, errors="ignore")
y_test = test_df[dep_vars]

# Calculate scale_pos_weight
scale_pos_weight = df['Class'].value_counts()[0] / df['Class'].value_counts()[1]

# %%
# Resample
from imblearn.over_sampling import SMOTE


def resample(X, y):
    sampler = SMOTE()
    X_res, y_res = sampler.fit_resample(X, y)
    return X_res, y_res

# %% [markdown]
# # Optimize

# %%
def objective(trial):
    params = dict(
        iterations=trial.suggest_int("iterations", 550, 650, step=50),
        learning_rate=trial.suggest_float("learning_rate", 0.02, 0.05, log=True),
        l2_leaf_reg=trial.suggest_float("l2_leaf_reg", 5.0, 6.0, step=0.1),
        depth=trial.suggest_int("depth", 3, 4),
        random_strength=trial.suggest_float("random_strength", 30.0, 75.0, step=5.0),
        border_count=trial.suggest_int("border_count", 1, 75),
        bagging_temperature=trial.suggest_float("bagging_temperature", 0.0, 0.5, step=0.1),
        grow_policy="SymmetricTree",
        verbose=0,
        scale_pos_weight=scale_pos_weight,
    )

    model = CatBoostClassifier(**params, eval_metric=BalancedLogLossMetric())

    skf = model_selection.RepeatedStratifiedKFold(n_splits=5, n_repeats=2)

    val_loss_list = []

    for i, (train_idx, val_idx) in enumerate(skf.split(X, y)):
        X_train = X.iloc[train_idx]
        y_train = y.iloc[train_idx].values.ravel()

        X_val = X.iloc[val_idx]
        y_val = y.iloc[val_idx].values.ravel()

        X_res, y_res = resample(X_train, y_train)
        model.fit(X_res, y_res)

        # model.fit(X_train, y_train)

        val_preds = model.predict_proba(X_val)
        val_loss = balanced_log_loss(y_val, val_preds)

        val_loss_list.append(val_loss)

    test_preds = model.predict_proba(X_test)
    test_loss = balanced_log_loss(y_test.values.ravel(), test_preds)
    mean_val_loss = np.mean(val_loss_list)

    return test_loss, test_loss - mean_val_loss

# %%
# optuna.delete_study(
#     study_name="catboost_no_categorical_resample",
#     storage="sqlite:////storage/optuna-final.db",
# )

# %%
pruner = optuna.pruners.SuccessiveHalvingPruner()
study = optuna.create_study(
    pruner=pruner,
    directions=["minimize", "minimize"],
    study_name="catboost_no_categorical_resample",
    storage="sqlite:///optuna.db",
    load_if_exists=True,
)
study.optimize(objective, n_trials=250)
# Out:
# [I 2023-08-06 17:56:40,353] A new study created in RDB with name: catboost_no_categorical_resample
# [I 2023-08-06 17:56:46,379] Trial 0 finished with values: [0.30669960995715934, 2.406453053677149e-05] and parameters: {'bagging_temperature': 0.4, 'border_count': 20, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.0307933265079735, 'random_strength': 45.0}.
# [I 2023-08-06 17:56:52,565] Trial 1 finished with values: [0.3356850389559058, 0.05727700801450203] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 41, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 6.0, 'learning_rate': 0.032986043381999716, 'random_strength': 30.0}.
# [I 2023-08-06 17:56:57,703] Trial 2 finished with values: [0.3211774365198566, 0.006917285129500073] and parameters: {'bagging_temperature': 0.1, 'border_count': 48, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.9, 'learning_rate': 0.029659759987400065, 'random_strength': 45.0}.
# [I 2023-08-06 17:57:03,666] Trial 3 finished with values: [0.2895137113905073, -0.030323623210573802] and parameters: {'bagging_temperature': 0.4, 'border_count': 54, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.02414580469838762, 'random_strength': 60.0}.
# [I 2023-08-06 17:57:11,347] Trial 4 finished with values: [0.3517687372431026, 0.018675814838049254] and parameters: {'bagging_temperature': 0.1, 'border_count': 65, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.0, 'learning_rate': 0.020887621114000533, 'random_strength': 55.0}.
# [I 2023-08-06 17:57:17,658] Trial 5 finished with values: [0.31027055551575455, 0.024527870614915626] and parameters: {'bagging_temperature': 0.0, 'border_count': 64, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.1, 'learning_rate': 0.027903095225435645, 'random_strength': 30.0}.
# [I 2023-08-06 17:57:22,706] Trial 6 finished with values: [0.3008959974083708, 0.027124414278664633] and parameters: {'bagging_temperature': 0.2, 'border_count': 48, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.040185245289809886, 'random_strength': 65.0}.
# [I 2023-08-06 17:57:28,562] Trial 7 finished with values: [0.34677097698978276, 0.08021443039159187] and parameters: {'bagging_temperature': 0.5, 'border_count': 29, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 6.0, 'learning_rate': 0.04405932094911714, 'random_strength': 75.0}.
# [I 2023-08-06 17:57:33,982] Trial 8 finished with values: [0.34890410318507864, 0.053247314102375876] and parameters: {'bagging_temperature': 0.2, 'border_count': 49, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.2, 'learning_rate': 0.03583934520134774, 'random_strength': 70.0}.
# [I 2023-08-06 17:57:38,559] Trial 9 finished with values: [0.33591440635692554, 0.00042765672758748874] and parameters: {'bagging_temperature': 0.1, 'border_count': 52, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.2, 'learning_rate': 0.022291218236688382, 'random_strength': 70.0}.
# [I 2023-08-06 17:57:43,883] Trial 10 finished with values: [0.3070507672305943, 0.0007099356505074206] and parameters: {'bagging_temperature': 0.5, 'border_count': 41, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.4, 'learning_rate': 0.045071076824348834, 'random_strength': 65.0}.
# [I 2023-08-06 17:57:48,298] Trial 11 finished with values: [0.3532795027446048, 0.03885392282530109] and parameters: {'bagging_temperature': 0.5, 'border_count': 18, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.9, 'learning_rate': 0.03798245681268987, 'random_strength': 75.0}.
# [I 2023-08-06 17:57:54,390] Trial 12 finished with values: [0.3170556840194552, 0.019338782599443494] and parameters: {'bagging_temperature': 0.1, 'border_count': 51, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.9, 'learning_rate': 0.022876607413041164, 'random_strength': 70.0}.
# [I 2023-08-06 17:57:59,669] Trial 13 finished with values: [0.3538906406110654, 0.012022066773852258] and parameters: {'bagging_temperature': 0.4, 'border_count': 37, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.027884378460777928, 'random_strength': 30.0}.
# [I 2023-08-06 17:58:05,084] Trial 14 finished with values: [0.30265158599179626, -0.008316479452121661] and parameters: {'bagging_temperature': 0.1, 'border_count': 3, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.024773216572807795, 'random_strength': 55.0}.
# [I 2023-08-06 17:58:10,461] Trial 15 finished with values: [0.41189437425270403, 0.06375541317124278] and parameters: {'bagging_temperature': 0.5, 'border_count': 49, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03789329000132877, 'random_strength': 70.0}.
# [I 2023-08-06 17:58:15,063] Trial 16 finished with values: [0.2662127903675529, -0.011080880997744125] and parameters: {'bagging_temperature': 0.4, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.6, 'learning_rate': 0.048228907942629205, 'random_strength': 65.0}.
# [I 2023-08-06 17:58:21,483] Trial 17 finished with values: [0.3823329101347879, 0.04357232534627242] and parameters: {'bagging_temperature': 0.5, 'border_count': 75, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.9, 'learning_rate': 0.0447877144191736, 'random_strength': 45.0}.
# [I 2023-08-06 17:58:26,860] Trial 18 finished with values: [0.2918944059825018, -0.01998625520358266] and parameters: {'bagging_temperature': 0.0, 'border_count': 6, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02601138912589874, 'random_strength': 75.0}.
# [I 2023-08-06 17:58:33,612] Trial 19 finished with values: [0.27501884201708265, -0.0325893029719459] and parameters: {'bagging_temperature': 0.0, 'border_count': 23, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03783230534959908, 'random_strength': 30.0}.
# [I 2023-08-06 17:58:38,830] Trial 20 finished with values: [0.3582405462880652, 0.056609131881039276] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 14, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.9, 'learning_rate': 0.03485949015743499, 'random_strength': 50.0}.
# [I 2023-08-06 17:58:44,544] Trial 21 finished with values: [0.35104232203563945, 0.03953578992853524] and parameters: {'bagging_temperature': 0.0, 'border_count': 71, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.4, 'learning_rate': 0.021019486624214323, 'random_strength': 35.0}.
# [I 2023-08-06 17:58:50,253] Trial 22 finished with values: [0.3169363540419365, 0.014981224394130577] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 72, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.028174187507369566, 'random_strength': 60.0}.
# [I 2023-08-06 17:58:55,029] Trial 23 finished with values: [0.35411879301886134, 0.05205492069469769] and parameters: {'bagging_temperature': 0.5, 'border_count': 58, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.04624477726073004, 'random_strength': 55.0}.
# [I 2023-08-06 17:58:59,614] Trial 24 finished with values: [0.30300687790043895, 0.0033035260051794135] and parameters: {'bagging_temperature': 0.0, 'border_count': 36, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.035362056654074735, 'random_strength': 50.0}.
# [I 2023-08-06 17:59:05,654] Trial 25 finished with values: [0.30678946240641153, 0.03194266203288115] and parameters: {'bagging_temperature': 0.5, 'border_count': 32, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.2, 'learning_rate': 0.032819054387768776, 'random_strength': 60.0}.
# [I 2023-08-06 17:59:11,031] Trial 26 finished with values: [0.3214876283894496, 0.03200901181115878] and parameters: {'bagging_temperature': 0.2, 'border_count': 48, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.03552773559212522, 'random_strength': 55.0}.
# [I 2023-08-06 17:59:15,763] Trial 27 finished with values: [0.336242944104119, 0.03152155340526136] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.023358559712659672, 'random_strength': 55.0}.
# [I 2023-08-06 17:59:21,665] Trial 28 finished with values: [0.3392428234930425, 0.041867342209029434] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 17, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.5, 'learning_rate': 0.032005098717822436, 'random_strength': 65.0}.
# [I 2023-08-06 17:59:26,958] Trial 29 finished with values: [0.29101035664009584, -0.048810784749601155] and parameters: {'bagging_temperature': 0.2, 'border_count': 44, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 17:59:31,953] Trial 30 finished with values: [0.299976131392215, 0.003211114911179924] and parameters: {'bagging_temperature': 0.1, 'border_count': 40, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.03980562819911422, 'random_strength': 30.0}.
# [I 2023-08-06 17:59:38,011] Trial 31 finished with values: [0.30291751686244955, 0.021765906015969616] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.6, 'learning_rate': 0.02293813262876192, 'random_strength': 55.0}.
# [I 2023-08-06 17:59:43,284] Trial 32 finished with values: [0.34076216140336757, 0.08018885669616177] and parameters: {'bagging_temperature': 0.1, 'border_count': 43, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.8, 'learning_rate': 0.039279199104389456, 'random_strength': 50.0}.
# [I 2023-08-06 17:59:47,909] Trial 33 finished with values: [0.35587619007944465, 0.02905078757825319] and parameters: {'bagging_temperature': 0.2, 'border_count': 32, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.02204943155958093, 'random_strength': 65.0}.
# [I 2023-08-06 17:59:54,023] Trial 34 finished with values: [0.3286054307197673, 0.024268900159765405] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 37, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.6, 'learning_rate': 0.02536759446634774, 'random_strength': 50.0}.
# [I 2023-08-06 17:59:59,266] Trial 35 finished with values: [0.4070645516552943, 0.07480352917020644] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 4, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.2, 'learning_rate': 0.03318859305905201, 'random_strength': 35.0}.
# [I 2023-08-06 18:00:05,048] Trial 36 finished with values: [0.3446930000762554, 0.05216974429385485] and parameters: {'bagging_temperature': 0.0, 'border_count': 25, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02163632698787582, 'random_strength': 45.0}.
# [I 2023-08-06 18:00:09,922] Trial 37 finished with values: [0.3040244998872484, -0.0023795519244048657] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 24, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.027136489805081772, 'random_strength': 60.0}.
# [I 2023-08-06 18:00:15,132] Trial 38 finished with values: [0.33989937254933184, 0.03961144798226607] and parameters: {'bagging_temperature': 0.0, 'border_count': 17, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.0301598154176396, 'random_strength': 70.0}.
# [I 2023-08-06 18:00:20,585] Trial 39 finished with values: [0.3123109634046553, -0.008277137478532315] and parameters: {'bagging_temperature': 0.1, 'border_count': 28, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.025631099482152503, 'random_strength': 65.0}.
# [I 2023-08-06 18:00:25,129] Trial 40 finished with values: [0.36259044453271627, 0.040778112249857834] and parameters: {'bagging_temperature': 0.4, 'border_count': 21, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 6.0, 'learning_rate': 0.02172234505652333, 'random_strength': 30.0}.
# [I 2023-08-06 18:00:29,984] Trial 41 finished with values: [0.3570472219750092, 0.04075005059614589] and parameters: {'bagging_temperature': 0.0, 'border_count': 30, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.4, 'learning_rate': 0.021946853944532486, 'random_strength': 35.0}.
# [I 2023-08-06 18:00:35,481] Trial 42 finished with values: [0.3338151817840888, 0.03559417651934893] and parameters: {'bagging_temperature': 0.4, 'border_count': 53, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.024736335825232224, 'random_strength': 35.0}.
# [I 2023-08-06 18:00:41,164] Trial 43 finished with values: [0.3163539195694844, 0.015525017656795592] and parameters: {'bagging_temperature': 0.2, 'border_count': 63, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.03536352645802756, 'random_strength': 55.0}.
# [I 2023-08-06 18:00:46,314] Trial 44 finished with values: [0.3011950719753235, 0.00439676497377689] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 48, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.0, 'learning_rate': 0.04054432930457563, 'random_strength': 45.0}.
# [I 2023-08-06 18:00:51,530] Trial 45 finished with values: [0.3041962377325209, 0.0014170393749602939] and parameters: {'bagging_temperature': 0.2, 'border_count': 65, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.0339987864690301, 'random_strength': 35.0}.
# [I 2023-08-06 18:00:56,320] Trial 46 finished with values: [0.2948910575172118, -0.004708884790096124] and parameters: {'bagging_temperature': 0.2, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02610122833283645, 'random_strength': 35.0}.
# [I 2023-08-06 18:01:01,561] Trial 47 finished with values: [0.3142014331980668, 0.03501929756587163] and parameters: {'bagging_temperature': 0.4, 'border_count': 70, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.03769144826529638, 'random_strength': 50.0}.
# [I 2023-08-06 18:01:06,521] Trial 48 finished with values: [0.2960131189044371, 0.01450650209743165] and parameters: {'bagging_temperature': 0.2, 'border_count': 23, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.04483932853946147, 'random_strength': 40.0}.
# [I 2023-08-06 18:01:12,086] Trial 49 finished with values: [0.3229457139347029, 0.013731141133926261] and parameters: {'bagging_temperature': 0.2, 'border_count': 52, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.8, 'learning_rate': 0.025021488828243097, 'random_strength': 75.0}.
# [I 2023-08-06 18:01:18,143] Trial 50 finished with values: [0.33606254190457646, 0.03562822391688164] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.6, 'learning_rate': 0.02526354011320225, 'random_strength': 55.0}.
# [I 2023-08-06 18:01:23,693] Trial 51 finished with values: [0.3439148765380798, 0.029977891396265] and parameters: {'bagging_temperature': 0.0, 'border_count': 3, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.024773216572807795, 'random_strength': 45.0}.
# [I 2023-08-06 18:01:28,451] Trial 52 finished with values: [0.3502308934804866, 0.040170481157915605] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 18:01:34,162] Trial 53 finished with values: [0.31228661552850345, -0.007571860783779638] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.027884378460777928, 'random_strength': 30.0}.
# [I 2023-08-06 18:01:38,923] Trial 54 finished with values: [0.3446223975728682, 0.03753884372209215] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.2, 'learning_rate': 0.022291218236688382, 'random_strength': 50.0}.
# [I 2023-08-06 18:01:43,594] Trial 55 finished with values: [0.3516948856226207, 0.06879875353396425] and parameters: {'bagging_temperature': 0.0, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.4, 'learning_rate': 0.028737822429880672, 'random_strength': 30.0}.
# [I 2023-08-06 18:01:48,291] Trial 56 finished with values: [0.2867973735031039, 0.010188880873046757] and parameters: {'bagging_temperature': 0.4, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.6, 'learning_rate': 0.03485949015743499, 'random_strength': 65.0}.
# [I 2023-08-06 18:01:53,309] Trial 57 finished with values: [0.37550960778946324, 0.08743807475052712] and parameters: {'bagging_temperature': 0.2, 'border_count': 40, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.03980562819911422, 'random_strength': 40.0}.
# [I 2023-08-06 18:01:58,059] Trial 58 finished with values: [0.29438524526698767, -0.027379385191316608] and parameters: {'bagging_temperature': 0.1, 'border_count': 52, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.0339987864690301, 'random_strength': 35.0}.
# [I 2023-08-06 18:02:04,450] Trial 59 finished with values: [0.284766436958168, -0.024942147730514064] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.2, 'learning_rate': 0.02293813262876192, 'random_strength': 60.0}.
# [I 2023-08-06 18:02:08,973] Trial 60 finished with values: [0.3378237937608019, 0.02756257850067595] and parameters: {'bagging_temperature': 0.1, 'border_count': 20, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.2, 'learning_rate': 0.022291218236688382, 'random_strength': 45.0}.
# [I 2023-08-06 18:02:14,329] Trial 61 finished with values: [0.30862116103156356, 0.0012925966317535176] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 67, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.03980562819911422, 'random_strength': 30.0}.
# [I 2023-08-06 18:02:19,623] Trial 62 finished with values: [0.25300780696272135, -0.05375153863227755] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02610122833283645, 'random_strength': 35.0}.
# [I 2023-08-06 18:02:25,833] Trial 63 finished with values: [0.29003468017801043, -0.013246683993354713] and parameters: {'bagging_temperature': 0.2, 'border_count': 52, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.025021488828243097, 'random_strength': 45.0}.
# [I 2023-08-06 18:02:30,688] Trial 64 finished with values: [0.32266391593968374, 0.004241270855841306] and parameters: {'bagging_temperature': 0.0, 'border_count': 6, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02601138912589874, 'random_strength': 70.0}.
# [I 2023-08-06 18:02:35,876] Trial 65 finished with values: [0.28884578966989133, -0.0008376463878712048] and parameters: {'bagging_temperature': 0.5, 'border_count': 44, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 18:02:41,305] Trial 66 finished with values: [0.31119760789252504, 0.014322979494526544] and parameters: {'bagging_temperature': 0.0, 'border_count': 54, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.4, 'learning_rate': 0.02414580469838762, 'random_strength': 30.0}.
# [I 2023-08-06 18:02:45,702] Trial 67 finished with values: [0.34329443879934257, 0.0038109817428130244] and parameters: {'bagging_temperature': 0.1, 'border_count': 24, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.8, 'learning_rate': 0.022291218236688382, 'random_strength': 60.0}.
# [I 2023-08-06 18:02:50,285] Trial 68 finished with values: [0.37284253313946986, 0.08095188747387977] and parameters: {'bagging_temperature': 0.4, 'border_count': 24, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.8, 'learning_rate': 0.027136489805081772, 'random_strength': 60.0}.
# [I 2023-08-06 18:02:55,033] Trial 69 finished with values: [0.31533067834814915, 0.0018165814878167708] and parameters: {'bagging_temperature': 0.2, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 6.0, 'learning_rate': 0.040185245289809886, 'random_strength': 65.0}.
# [I 2023-08-06 18:03:00,335] Trial 70 finished with values: [0.36138971985109325, 0.07086322524769106] and parameters: {'bagging_temperature': 0.2, 'border_count': 70, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.03769144826529638, 'random_strength': 30.0}.
# [I 2023-08-06 18:03:06,162] Trial 71 finished with values: [0.3414965374667754, 0.06396770190639839] and parameters: {'bagging_temperature': 0.4, 'border_count': 28, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.8, 'learning_rate': 0.025631099482152503, 'random_strength': 65.0}.
# [I 2023-08-06 18:03:12,059] Trial 72 finished with values: [0.3109092079272421, 0.035433282449349734] and parameters: {'bagging_temperature': 0.5, 'border_count': 54, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.02414580469838762, 'random_strength': 55.0}.
# [I 2023-08-06 18:03:17,430] Trial 73 finished with values: [0.3751827389465451, 0.06303206648102988] and parameters: {'bagging_temperature': 0.4, 'border_count': 37, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.03536352645802756, 'random_strength': 55.0}.
# [I 2023-08-06 18:03:22,643] Trial 74 finished with values: [0.3825879252160496, 0.10245606694904658] and parameters: {'bagging_temperature': 0.2, 'border_count': 48, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.04851617607779446, 'random_strength': 45.0}.
# [I 2023-08-06 18:03:28,935] Trial 75 finished with values: [0.2782014278427288, 0.009613883527636924] and parameters: {'bagging_temperature': 0.0, 'border_count': 36, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.0307933265079735, 'random_strength': 50.0}.
# [I 2023-08-06 18:03:36,060] Trial 76 finished with values: [0.293987097398922, 0.010669425749304795] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 37, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.7, 'learning_rate': 0.02536759446634774, 'random_strength': 55.0}.
# [I 2023-08-06 18:03:41,893] Trial 77 finished with values: [0.29760054262998886, -0.00404212231191492] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 12, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 6.0, 'learning_rate': 0.029020951753696518, 'random_strength': 50.0}.
# [I 2023-08-06 18:03:48,395] Trial 78 finished with values: [0.33271486177419424, 0.057959073338997746] and parameters: {'bagging_temperature': 0.2, 'border_count': 48, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 6.0, 'learning_rate': 0.04405932094911714, 'random_strength': 75.0}.
# [I 2023-08-06 18:03:55,033] Trial 79 finished with values: [0.2958888993310829, 0.006068605512977887] and parameters: {'bagging_temperature': 0.0, 'border_count': 48, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.9, 'learning_rate': 0.022876607413041164, 'random_strength': 45.0}.
# [I 2023-08-06 18:03:59,865] Trial 80 finished with values: [0.315516218455089, 0.0378836872943793] and parameters: {'bagging_temperature': 0.0, 'border_count': 36, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.035362056654074735, 'random_strength': 50.0}.
# [I 2023-08-06 18:04:04,589] Trial 81 finished with values: [0.34082417736629017, 0.04093850745873434] and parameters: {'bagging_temperature': 0.4, 'border_count': 32, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.6, 'learning_rate': 0.048228907942629205, 'random_strength': 65.0}.
# [I 2023-08-06 18:04:10,470] Trial 82 finished with values: [0.3314281633275876, 0.04564104695143484] and parameters: {'bagging_temperature': 0.2, 'border_count': 23, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03552773559212522, 'random_strength': 55.0}.
# [I 2023-08-06 18:04:14,683] Trial 83 finished with values: [0.34348704268172797, 0.020283435570997044] and parameters: {'bagging_temperature': 0.4, 'border_count': 3, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02610122833283645, 'random_strength': 55.0}.
# [I 2023-08-06 18:04:19,522] Trial 84 finished with values: [0.380913689903685, 0.09764251002314478] and parameters: {'bagging_temperature': 0.2, 'border_count': 23, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.2, 'learning_rate': 0.04483932853946147, 'random_strength': 70.0}.
# [I 2023-08-06 18:04:25,234] Trial 85 finished with values: [0.29639335961508123, 0.021701199105940316] and parameters: {'bagging_temperature': 0.4, 'border_count': 54, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.04465715496196864, 'random_strength': 50.0}.
# [I 2023-08-06 18:04:30,290] Trial 86 finished with values: [0.3397533079971415, 0.03570361717590781] and parameters: {'bagging_temperature': 0.2, 'border_count': 54, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.02414580469838762, 'random_strength': 40.0}.
# [I 2023-08-06 18:04:35,511] Trial 87 finished with values: [0.3234053522117478, 0.060514118934938965] and parameters: {'bagging_temperature': 0.5, 'border_count': 65, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.04624477726073004, 'random_strength': 35.0}.
# [I 2023-08-06 18:04:41,096] Trial 88 finished with values: [0.32995886428308213, 0.02596767859379817] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 44, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.02610122833283645, 'random_strength': 50.0}.
# [I 2023-08-06 18:04:46,561] Trial 89 finished with values: [0.2822665811622373, 0.007199530371182983] and parameters: {'bagging_temperature': 0.1, 'border_count': 28, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02968031751825767, 'random_strength': 65.0}.
# [I 2023-08-06 18:04:52,276] Trial 90 finished with values: [0.3326184076200288, 0.012146457666755373] and parameters: {'bagging_temperature': 0.0, 'border_count': 72, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.02163632698787582, 'random_strength': 60.0}.
# [I 2023-08-06 18:04:58,098] Trial 91 finished with values: [0.3021957441624267, 0.022310265798876905] and parameters: {'bagging_temperature': 0.0, 'border_count': 23, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.6, 'learning_rate': 0.03783230534959908, 'random_strength': 65.0}.
# [I 2023-08-06 18:05:03,182] Trial 92 finished with values: [0.3840953238387972, 0.05920551349078795] and parameters: {'bagging_temperature': 0.2, 'border_count': 44, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.0, 'learning_rate': 0.04483932853946147, 'random_strength': 35.0}.
# [I 2023-08-06 18:05:07,940] Trial 93 finished with values: [0.3371566071306509, 0.030004971671833358] and parameters: {'bagging_temperature': 0.4, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02897917418998173, 'random_strength': 65.0}.
# [I 2023-08-06 18:05:12,330] Trial 94 finished with values: [0.33381049757927306, -0.0013065855278183713] and parameters: {'bagging_temperature': 0.2, 'border_count': 6, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.020889845339017353, 'random_strength': 75.0}.
# [I 2023-08-06 18:05:18,443] Trial 95 finished with values: [0.3407050956330318, 0.03842917241099769] and parameters: {'bagging_temperature': 0.2, 'border_count': 49, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.4, 'learning_rate': 0.0339987864690301, 'random_strength': 70.0}.
# [I 2023-08-06 18:05:24,311] Trial 96 finished with values: [0.34103116848990317, 0.05695372664256321] and parameters: {'bagging_temperature': 0.5, 'border_count': 41, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.4, 'learning_rate': 0.045071076824348834, 'random_strength': 65.0}.
# [I 2023-08-06 18:05:29,400] Trial 97 finished with values: [0.35771615165369836, 0.060624018876269725] and parameters: {'bagging_temperature': 0.2, 'border_count': 6, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.7, 'learning_rate': 0.02601138912589874, 'random_strength': 65.0}.
# [I 2023-08-06 18:05:34,640] Trial 98 finished with values: [0.37041634546198393, 0.09551601615444166] and parameters: {'bagging_temperature': 0.0, 'border_count': 48, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.035362056654074735, 'random_strength': 65.0}.
# [I 2023-08-06 18:05:40,302] Trial 99 finished with values: [0.36375850284793837, 0.057635277800122675] and parameters: {'bagging_temperature': 0.4, 'border_count': 37, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.027884378460777928, 'random_strength': 30.0}.
# [I 2023-08-06 18:05:46,069] Trial 100 finished with values: [0.3082837929178028, -0.00875618036652076] and parameters: {'bagging_temperature': 0.2, 'border_count': 64, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.04483932853946147, 'random_strength': 40.0}.
# [I 2023-08-06 18:05:51,697] Trial 101 finished with values: [0.3205652106899318, 0.013873992488138198] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 28, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.025631099482152503, 'random_strength': 60.0}.
# [I 2023-08-06 18:05:57,277] Trial 102 finished with values: [0.34473033050689345, 0.05713659717470271] and parameters: {'bagging_temperature': 0.1, 'border_count': 15, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03980562819911422, 'random_strength': 75.0}.
# [I 2023-08-06 18:06:05,875] Trial 103 finished with values: [0.34164186786209405, 0.040292395879810816] and parameters: {'bagging_temperature': 0.2, 'border_count': 44, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.03536352645802756, 'random_strength': 55.0}.
# [I 2023-08-06 18:06:11,560] Trial 104 finished with values: [0.36302171483103873, 0.03216123733629034] and parameters: {'bagging_temperature': 0.2, 'border_count': 36, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.020889845339017353, 'random_strength': 50.0}.
# [I 2023-08-06 18:06:16,587] Trial 105 finished with values: [0.33866502398624004, 0.03155259956004386] and parameters: {'bagging_temperature': 0.0, 'border_count': 23, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.6, 'learning_rate': 0.03783230534959908, 'random_strength': 65.0}.
# [I 2023-08-06 18:06:22,603] Trial 106 finished with values: [0.39418280403981854, 0.08720730566551449] and parameters: {'bagging_temperature': 0.1, 'border_count': 52, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.03696223503892775, 'random_strength': 50.0}.
# [I 2023-08-06 18:06:28,623] Trial 107 finished with values: [0.3118757907124852, 0.013722043341064083] and parameters: {'bagging_temperature': 0.0, 'border_count': 23, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03783230534959908, 'random_strength': 30.0}.
# [I 2023-08-06 18:06:34,441] Trial 108 finished with values: [0.27184966887887263, -0.012642572269325303] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 18:06:40,215] Trial 109 finished with values: [0.28403720979126673, -0.02468436871420049] and parameters: {'bagging_temperature': 0.0, 'border_count': 6, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.020071846703781874, 'random_strength': 75.0}.
# [I 2023-08-06 18:06:44,920] Trial 110 finished with values: [0.34090595742741886, 0.014783172870390937] and parameters: {'bagging_temperature': 0.0, 'border_count': 24, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.8, 'learning_rate': 0.022291218236688382, 'random_strength': 70.0}.
# [I 2023-08-06 18:06:51,543] Trial 111 finished with values: [0.2980257088537514, -0.005195542906136996] and parameters: {'bagging_temperature': 0.2, 'border_count': 66, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.020889845339017353, 'random_strength': 75.0}.
# [I 2023-08-06 18:06:56,844] Trial 112 finished with values: [0.27953713586315504, -0.029476700452550297] and parameters: {'bagging_temperature': 0.4, 'border_count': 69, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.048228907942629205, 'random_strength': 50.0}.
# [I 2023-08-06 18:07:02,768] Trial 113 finished with values: [0.3138482825089692, 0.01245351830269148] and parameters: {'bagging_temperature': 0.4, 'border_count': 54, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.02414580469838762, 'random_strength': 60.0}.
# [I 2023-08-06 18:07:08,473] Trial 114 finished with values: [0.3337725678983246, 0.03564807061204517] and parameters: {'bagging_temperature': 0.1, 'border_count': 3, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.024773216572807795, 'random_strength': 30.0}.
# [I 2023-08-06 18:07:14,033] Trial 115 finished with values: [0.29263692149207604, -0.017959338304444017] and parameters: {'bagging_temperature': 0.1, 'border_count': 48, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.7, 'learning_rate': 0.027884378460777928, 'random_strength': 30.0}.
# [I 2023-08-06 18:07:19,659] Trial 116 finished with values: [0.3297983717720066, 0.026801890516545634] and parameters: {'bagging_temperature': 0.1, 'border_count': 51, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02968031751825767, 'random_strength': 65.0}.
# [I 2023-08-06 18:07:24,498] Trial 117 finished with values: [0.3256042075458326, 0.02634959934064096] and parameters: {'bagging_temperature': 0.4, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.9, 'learning_rate': 0.048228907942629205, 'random_strength': 45.0}.
# [I 2023-08-06 18:07:29,264] Trial 118 finished with values: [0.335005136850646, 0.025966537289214997] and parameters: {'bagging_temperature': 0.5, 'border_count': 48, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 6.0, 'learning_rate': 0.028174187507369566, 'random_strength': 30.0}.
# [I 2023-08-06 18:07:34,781] Trial 119 finished with values: [0.31518861362112377, 0.025698863474911238] and parameters: {'bagging_temperature': 0.4, 'border_count': 28, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.02414580469838762, 'random_strength': 60.0}.
# [I 2023-08-06 18:07:39,816] Trial 120 finished with values: [0.3148320645021653, 0.017032045626610648] and parameters: {'bagging_temperature': 0.0, 'border_count': 26, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02601138912589874, 'random_strength': 35.0}.
# [I 2023-08-06 18:07:46,304] Trial 121 finished with values: [0.27816058026389345, -0.004829260378467981] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.2, 'learning_rate': 0.02293813262876192, 'random_strength': 60.0}.
# [I 2023-08-06 18:07:51,390] Trial 122 finished with values: [0.30051577185890016, 0.006846075861110301] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 41, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.4, 'learning_rate': 0.035362056654074735, 'random_strength': 50.0}.
# [I 2023-08-06 18:07:57,914] Trial 123 finished with values: [0.3110771515149426, 0.016496240460561806] and parameters: {'bagging_temperature': 0.1, 'border_count': 24, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.024773216572807795, 'random_strength': 55.0}.
# [I 2023-08-06 18:08:04,097] Trial 124 finished with values: [0.37789025548989696, 0.10122841901938512] and parameters: {'bagging_temperature': 0.4, 'border_count': 67, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.04465715496196864, 'random_strength': 50.0}.
# [I 2023-08-06 18:08:08,952] Trial 125 finished with values: [0.3492580428971432, 0.03622846792951123] and parameters: {'bagging_temperature': 0.1, 'border_count': 48, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.4, 'learning_rate': 0.029659759987400065, 'random_strength': 30.0}.
# [I 2023-08-06 18:08:13,351] Trial 126 finished with values: [0.32780009586878733, 0.009185578723926335] and parameters: {'bagging_temperature': 0.1, 'border_count': 3, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.1, 'learning_rate': 0.024773216572807795, 'random_strength': 35.0}.
# [I 2023-08-06 18:08:19,174] Trial 127 finished with values: [0.3532880826077546, 0.059296078165747446] and parameters: {'bagging_temperature': 0.0, 'border_count': 28, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.03783230534959908, 'random_strength': 65.0}.
# [I 2023-08-06 18:08:24,382] Trial 128 finished with values: [0.3459904768547932, 0.05554182764072246] and parameters: {'bagging_temperature': 0.0, 'border_count': 44, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 6.0, 'learning_rate': 0.040185245289809886, 'random_strength': 65.0}.
# [I 2023-08-06 18:08:29,665] Trial 129 finished with values: [0.339718530250327, 0.04829604297761475] and parameters: {'bagging_temperature': 0.1, 'border_count': 48, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.6, 'learning_rate': 0.02335679685305275, 'random_strength': 55.0}.
# [I 2023-08-06 18:08:34,960] Trial 130 finished with values: [0.3355491339813175, 0.03280938808376599] and parameters: {'bagging_temperature': 0.5, 'border_count': 52, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.2, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 18:08:40,332] Trial 131 finished with values: [0.31649666544839145, -0.0023161859367807347] and parameters: {'bagging_temperature': 0.1, 'border_count': 54, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 6.0, 'learning_rate': 0.022291218236688382, 'random_strength': 70.0}.
# [I 2023-08-06 18:08:45,449] Trial 132 finished with values: [0.3925075334440618, 0.06835912218970647] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 67, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.022291218236688382, 'random_strength': 70.0}.
# [I 2023-08-06 18:08:50,605] Trial 133 finished with values: [0.4013893048823431, 0.0849148735496999] and parameters: {'bagging_temperature': 0.4, 'border_count': 54, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.04465715496196864, 'random_strength': 30.0}.
# [I 2023-08-06 18:08:55,523] Trial 134 finished with values: [0.3284270863033778, 0.021419698963159484] and parameters: {'bagging_temperature': 0.0, 'border_count': 6, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02601138912589874, 'random_strength': 55.0}.
# [I 2023-08-06 18:08:59,897] Trial 135 finished with values: [0.3141496454012273, -0.004299477429878129] and parameters: {'bagging_temperature': 0.0, 'border_count': 6, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02601138912589874, 'random_strength': 55.0}.
# [I 2023-08-06 18:09:05,490] Trial 136 finished with values: [0.3176117341512126, -0.010963174262808795] and parameters: {'bagging_temperature': 0.4, 'border_count': 3, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.024773216572807795, 'random_strength': 55.0}.
# [I 2023-08-06 18:09:10,022] Trial 137 finished with values: [0.3369297605134797, 0.0601250163719389] and parameters: {'bagging_temperature': 0.0, 'border_count': 36, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.8, 'learning_rate': 0.04229855821997396, 'random_strength': 50.0}.
# [I 2023-08-06 18:09:15,406] Trial 138 finished with values: [0.33398892476936676, 0.03963235408461446] and parameters: {'bagging_temperature': 0.2, 'border_count': 23, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.6, 'learning_rate': 0.03783230534959908, 'random_strength': 30.0}.
# [I 2023-08-06 18:09:20,141] Trial 139 finished with values: [0.3275708585757808, 0.037808045830628745] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02610122833283645, 'random_strength': 30.0}.
# [I 2023-08-06 18:09:25,050] Trial 140 finished with values: [0.3505054667313322, 0.06610005595547908] and parameters: {'bagging_temperature': 0.0, 'border_count': 36, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.6, 'learning_rate': 0.035362056654074735, 'random_strength': 50.0}.
# [I 2023-08-06 18:09:30,423] Trial 141 finished with values: [0.3494212789321432, 0.061255347550938866] and parameters: {'bagging_temperature': 0.1, 'border_count': 52, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.9, 'learning_rate': 0.04472624456927732, 'random_strength': 45.0}.
# [I 2023-08-06 18:09:35,172] Trial 142 finished with values: [0.4099912734257757, 0.08754926323710971] and parameters: {'bagging_temperature': 0.2, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 18:09:40,929] Trial 143 finished with values: [0.32640796956797996, 0.03281078294064815] and parameters: {'bagging_temperature': 0.5, 'border_count': 64, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.8, 'learning_rate': 0.045071076824348834, 'random_strength': 50.0}.
# [I 2023-08-06 18:09:47,474] Trial 144 finished with values: [0.3393396864732519, 0.05256421801236438] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 6.0, 'learning_rate': 0.027903095225435645, 'random_strength': 60.0}.
# [I 2023-08-06 18:09:52,175] Trial 145 finished with values: [0.3086986432214538, 0.02055405216296441] and parameters: {'bagging_temperature': 0.0, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.7, 'learning_rate': 0.028174187507369566, 'random_strength': 65.0}.
# [I 2023-08-06 18:09:56,889] Trial 146 finished with values: [0.35995878079820726, 0.0641790885968005] and parameters: {'bagging_temperature': 0.4, 'border_count': 52, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.03485949015743499, 'random_strength': 65.0}.
# [I 2023-08-06 18:10:01,604] Trial 147 finished with values: [0.32642596775368343, 0.026605377832622568] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.04101578623612391, 'random_strength': 35.0}.
# [I 2023-08-06 18:10:06,151] Trial 148 finished with values: [0.3282996025015669, 0.029733811261674126] and parameters: {'bagging_temperature': 0.0, 'border_count': 23, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.9, 'learning_rate': 0.022876607413041164, 'random_strength': 40.0}.
# [I 2023-08-06 18:10:11,807] Trial 149 finished with values: [0.28540585139353225, -0.028079198253956883] and parameters: {'bagging_temperature': 0.0, 'border_count': 6, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02601138912589874, 'random_strength': 75.0}.
# [I 2023-08-06 18:10:16,796] Trial 150 finished with values: [0.3265973609429154, 0.03837026133858412] and parameters: {'bagging_temperature': 0.4, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.6, 'learning_rate': 0.048228907942629205, 'random_strength': 65.0}.
# [I 2023-08-06 18:10:22,028] Trial 151 finished with values: [0.3485114249016021, 0.013986441705603148] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.048228907942629205, 'random_strength': 65.0}.
# [I 2023-08-06 18:10:27,618] Trial 152 finished with values: [0.31070196580631676, 0.014836783521784636] and parameters: {'bagging_temperature': 0.1, 'border_count': 48, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.8, 'learning_rate': 0.027884378460777928, 'random_strength': 30.0}.
# [I 2023-08-06 18:10:33,368] Trial 153 finished with values: [0.2768341108114387, 0.0027247293459334854] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 12, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 6.0, 'learning_rate': 0.029020951753696518, 'random_strength': 35.0}.
# [I 2023-08-06 18:10:38,866] Trial 154 finished with values: [0.3214454574214737, 0.011889018137597185] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.020889845339017353, 'random_strength': 75.0}.
# [I 2023-08-06 18:10:43,802] Trial 155 finished with values: [0.3807273100020351, 0.03470908717932086] and parameters: {'bagging_temperature': 0.4, 'border_count': 12, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.048228907942629205, 'random_strength': 65.0}.
# [I 2023-08-06 18:10:48,334] Trial 156 finished with values: [0.3109390727126868, -0.019813790381306207] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 23, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03783230534959908, 'random_strength': 35.0}.
# [I 2023-08-06 18:10:53,035] Trial 157 finished with values: [0.4138716541073081, 0.11709584912729354] and parameters: {'bagging_temperature': 0.2, 'border_count': 44, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02610122833283645, 'random_strength': 30.0}.
# [I 2023-08-06 18:11:02,438] Trial 158 finished with values: [0.3250924148456565, 0.052105903056729796] and parameters: {'bagging_temperature': 0.2, 'border_count': 44, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.04483932853946147, 'random_strength': 65.0}.
# [I 2023-08-06 18:11:07,749] Trial 159 finished with values: [0.27738130361213487, -0.04824448679836585] and parameters: {'bagging_temperature': 0.4, 'border_count': 44, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.2, 'learning_rate': 0.048228907942629205, 'random_strength': 65.0}.
# [I 2023-08-06 18:11:12,934] Trial 160 finished with values: [0.3406970264564973, 0.021914817245915097] and parameters: {'bagging_temperature': 0.0, 'border_count': 48, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.9, 'learning_rate': 0.022876607413041164, 'random_strength': 45.0}.
# [I 2023-08-06 18:11:19,769] Trial 161 finished with values: [0.29001065883220833, -0.0023075460021072525] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.2, 'learning_rate': 0.02293813262876192, 'random_strength': 75.0}.
# [I 2023-08-06 18:11:25,365] Trial 162 finished with values: [0.3321005998576814, 0.03180632418925683] and parameters: {'bagging_temperature': 0.2, 'border_count': 11, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.020548055611272795, 'random_strength': 75.0}.
# [I 2023-08-06 18:11:30,641] Trial 163 finished with values: [0.3548587798724361, 0.06619088768321235] and parameters: {'bagging_temperature': 0.4, 'border_count': 72, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.027136489805081772, 'random_strength': 60.0}.
# [I 2023-08-06 18:11:35,670] Trial 164 finished with values: [0.29124888936610444, -0.014494433738031942] and parameters: {'bagging_temperature': 0.2, 'border_count': 64, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.048228907942629205, 'random_strength': 40.0}.
# [I 2023-08-06 18:11:40,264] Trial 165 finished with values: [0.31830020709131013, 0.0057738426672000465] and parameters: {'bagging_temperature': 0.0, 'border_count': 6, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02601138912589874, 'random_strength': 75.0}.
# [I 2023-08-06 18:11:45,517] Trial 166 finished with values: [0.4268896886269646, 0.11332235546159508] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 66, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.03980562819911422, 'random_strength': 75.0}.
# ...
# [I 2023-08-06 18:14:20,429] Trial 194 finished with values: [0.3340316356332918, 0.03553961084978097] and parameters: {'bagging_temperature': 0.1, 'border_count': 6, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02601138912589874, 'random_strength': 35.0}.
# [I 2023-08-06 18:14:26,305] Trial 195 finished with values: [0.34353915484760955, 0.05929385504813761] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.024773216572807795, 'random_strength': 30.0}.
# [I 2023-08-06 18:14:31,400] Trial 196 finished with values: [0.36525199795267443, 0.0768034651539598] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 24, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.027136489805081772, 'random_strength': 35.0}.
# [I 2023-08-06 18:14:36,763] Trial 197 finished with values: [0.31594150756392175, 0.024758314653321623] and parameters: {'bagging_temperature': 0.0, 'border_count': 41, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.4, 'learning_rate': 0.035362056654074735, 'random_strength': 50.0}.
# [I 2023-08-06 18:14:42,894] Trial 198 finished with values: [0.3781799575302516, 0.06023636042712022] and parameters: {'bagging_temperature': 0.4, 'border_count': 65, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.027884378460777928, 'random_strength': 35.0}.
# [I 2023-08-06 18:14:49,243] Trial 199 finished with values: [0.3048755031912077, 0.023678872651314076] and parameters: {'bagging_temperature': 0.0, 'border_count': 64, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.2, 'learning_rate': 0.022876607413041164, 'random_strength': 60.0}.
# [I 2023-08-06 18:14:54,734] Trial 200 finished with values: [0.32319828277325136, 0.013487968643835946] and parameters: {'bagging_temperature': 0.1, 'border_count': 6, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 6.0, 'learning_rate': 0.020071846703781874, 'random_strength': 35.0}.
# [I 2023-08-06 18:15:00,162] Trial 201 finished with values: [0.40050487328369594, 0.08772119392746969] and parameters: {'bagging_temperature': 0.1, 'border_count': 37, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.7, 'learning_rate': 0.027884378460777928, 'random_strength': 55.0}.
# [I 2023-08-06 18:15:06,334] Trial 202 finished with values: [0.31741076318940376, 0.023508080966271105] and parameters: {'bagging_temperature': 0.0, 'border_count': 28, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.020071846703781874, 'random_strength': 50.0}.
# [I 2023-08-06 18:15:11,824] Trial 203 finished with values: [0.2773977942193719, -0.014825835710399915] and parameters: {'bagging_temperature': 0.4, 'border_count': 56, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 6.0, 'learning_rate': 0.048228907942629205, 'random_strength': 50.0}.
# [I 2023-08-06 18:15:17,159] Trial 204 finished with values: [0.3064238697316132, 0.013433800496610804] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 12, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.029020951753696518, 'random_strength': 35.0}.
# [I 2023-08-06 18:15:22,118] Trial 205 finished with values: [0.3375672235786922, 0.030588210941959182] and parameters: {'bagging_temperature': 0.0, 'border_count': 23, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.2, 'learning_rate': 0.03783230534959908, 'random_strength': 60.0}.
# [I 2023-08-06 18:15:27,587] Trial 206 finished with values: [0.3360214792108702, 0.01571734922933199] and parameters: {'bagging_temperature': 0.4, 'border_count': 3, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.027498556316182816, 'random_strength': 30.0}.
# [I 2023-08-06 18:15:33,709] Trial 207 finished with values: [0.38383554575193984, 0.0873198837633341] and parameters: {'bagging_temperature': 0.2, 'border_count': 64, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.8, 'learning_rate': 0.0323491026763784, 'random_strength': 40.0}.
# [I 2023-08-06 18:15:39,624] Trial 208 finished with values: [0.3086813975785206, 0.007455149525930682] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 18:15:44,511] Trial 209 finished with values: [0.2919141075296494, -0.010144766565784558] and parameters: {'bagging_temperature': 0.2, 'border_count': 18, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.04483932853946147, 'random_strength': 40.0}.
# [I 2023-08-06 18:15:50,448] Trial 210 finished with values: [0.361808708089914, 0.07664854893046791] and parameters: {'bagging_temperature': 0.2, 'border_count': 64, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.8, 'learning_rate': 0.027884378460777928, 'random_strength': 30.0}.
# [I 2023-08-06 18:15:56,459] Trial 211 finished with values: [0.28600878625998655, 0.008556383129286693] and parameters: {'bagging_temperature': 0.2, 'border_count': 52, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.5, 'learning_rate': 0.025021488828243097, 'random_strength': 75.0}.
# [I 2023-08-06 18:16:01,618] Trial 212 finished with values: [0.3412510261229263, 0.04069829157717708] and parameters: {'bagging_temperature': 0.2, 'border_count': 48, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.0, 'learning_rate': 0.04054432930457563, 'random_strength': 45.0}.
# [I 2023-08-06 18:16:07,448] Trial 213 finished with values: [0.2786397381892814, -0.0284233333925607] and parameters: {'bagging_temperature': 0.2, 'border_count': 40, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.026107403674035714, 'random_strength': 45.0}.
# [I 2023-08-06 18:16:13,831] Trial 214 finished with values: [0.3196614275964676, 0.023326863252722263] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02610122833283645, 'random_strength': 55.0}.
# [I 2023-08-06 18:16:19,180] Trial 215 finished with values: [0.2916106893556416, -0.015744163867817906] and parameters: {'bagging_temperature': 0.1, 'border_count': 52, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.8, 'learning_rate': 0.025631099482152503, 'random_strength': 35.0}.
# [I 2023-08-06 18:16:24,963] Trial 216 finished with values: [0.3279996415691671, 0.027025971116872605] and parameters: {'bagging_temperature': 0.0, 'border_count': 36, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.0, 'learning_rate': 0.0307933265079735, 'random_strength': 50.0}.
# [I 2023-08-06 18:16:31,376] Trial 217 finished with values: [0.27921154942063303, -0.023152328379880516] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 64, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.2, 'learning_rate': 0.02293813262876192, 'random_strength': 50.0}.
# [I 2023-08-06 18:16:36,725] Trial 218 finished with values: [0.2998988923409971, 0.01162153832040852] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 69, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02610122833283645, 'random_strength': 50.0}.
# [I 2023-08-06 18:16:42,039] Trial 219 finished with values: [0.28306607102989384, -0.016049147354213866] and parameters: {'bagging_temperature': 0.0, 'border_count': 44, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.4, 'learning_rate': 0.036147747680740396, 'random_strength': 30.0}.
# [I 2023-08-06 18:16:47,126] Trial 220 finished with values: [0.3384351602946655, 0.0384058171802617] and parameters: {'bagging_temperature': 0.4, 'border_count': 48, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.4, 'learning_rate': 0.027884378460777928, 'random_strength': 30.0}.
# [I 2023-08-06 18:16:51,799] Trial 221 finished with values: [0.34603288429649376, 0.0502636205226471] and parameters: {'bagging_temperature': 0.0, 'border_count': 23, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03783230534959908, 'random_strength': 35.0}.
# [I 2023-08-06 18:16:57,760] Trial 222 finished with values: [0.31443749161310197, 0.03153225193755893] and parameters: {'bagging_temperature': 0.1, 'border_count': 29, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 6.0, 'learning_rate': 0.02610122833283645, 'random_strength': 35.0}.
# [I 2023-08-06 18:17:02,210] Trial 223 finished with values: [0.3579454586547249, 0.05890510086988149] and parameters: {'bagging_temperature': 0.0, 'border_count': 12, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 6.0, 'learning_rate': 0.03783230534959908, 'random_strength': 35.0}.
# [I 2023-08-06 18:17:08,588] Trial 224 finished with values: [0.3294455428997372, 0.03667569671148346] and parameters: {'bagging_temperature': 0.4, 'border_count': 64, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.2, 'learning_rate': 0.02293813262876192, 'random_strength': 75.0}.
# [I 2023-08-06 18:17:14,370] Trial 225 finished with values: [0.3135355458744484, 0.003874928588956328] and parameters: {'bagging_temperature': 0.4, 'border_count': 44, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.6, 'learning_rate': 0.022127013116316745, 'random_strength': 65.0}.
# [I 2023-08-06 18:17:19,870] Trial 226 finished with values: [0.3689644274849114, 0.07191361684634229] and parameters: {'bagging_temperature': 0.1, 'border_count': 28, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.7, 'learning_rate': 0.02536759446634774, 'random_strength': 65.0}.
# [I 2023-08-06 18:17:25,965] Trial 227 finished with values: [0.3479396846366016, 0.04869415641499353] and parameters: {'bagging_temperature': 0.0, 'border_count': 36, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.03749207987566769, 'random_strength': 50.0}.
# [I 2023-08-06 18:17:32,088] Trial 228 finished with values: [0.29746417503697825, 0.00824635069214491] and parameters: {'bagging_temperature': 0.30000000000000004, 'border_count': 44, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 18:17:37,158] Trial 229 finished with values: [0.32299038688569753, 0.02572116779567385] and parameters: {'bagging_temperature': 0.0, 'border_count': 29, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.9, 'learning_rate': 0.02601138912589874, 'random_strength': 30.0}.
# [I 2023-08-06 18:17:42,570] Trial 230 finished with values: [0.3252251736184271, 0.00936619901065594] and parameters: {'bagging_temperature': 0.2, 'border_count': 65, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.0339987864690301, 'random_strength': 30.0}.
# [I 2023-08-06 18:17:46,842] Trial 231 finished with values: [0.3419133768188868, 0.058652653649131525] and parameters: {'bagging_temperature': 0.2, 'border_count': 6, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.0, 'learning_rate': 0.041409145384778336, 'random_strength': 40.0}.
# [I 2023-08-06 18:17:51,963] Trial 232 finished with values: [0.2789962321493395, -0.004853490281432726] and parameters: {'bagging_temperature': 0.0, 'border_count': 41, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03783230534959908, 'random_strength': 50.0}.
# [I 2023-08-06 18:17:57,424] Trial 233 finished with values: [0.3429563839041135, 0.03788252712684437] and parameters: {'bagging_temperature': 0.4, 'border_count': 26, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 6.0, 'learning_rate': 0.02414580469838762, 'random_strength': 60.0}.
# [I 2023-08-06 18:18:02,730] Trial 234 finished with values: [0.24030907977238783, -0.02970141038842386] and parameters: {'bagging_temperature': 0.2, 'border_count': 44, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.048228907942629205, 'random_strength': 40.0}.
# [I 2023-08-06 18:18:08,124] Trial 235 finished with values: [0.30291903428442385, -0.0002717960848305778] and parameters: {'bagging_temperature': 0.4, 'border_count': 54, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.9, 'learning_rate': 0.02414580469838762, 'random_strength': 30.0}.
# [I 2023-08-06 18:18:13,769] Trial 236 finished with values: [0.33238392534241307, 0.03594791801759356] and parameters: {'bagging_temperature': 0.1, 'border_count': 44, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 18:18:19,803] Trial 237 finished with values: [0.35413892657593365, 0.04504732218854213] and parameters: {'bagging_temperature': 0.4, 'border_count': 20, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 6.0, 'learning_rate': 0.0307933265079735, 'random_strength': 35.0}.
# [I 2023-08-06 18:18:24,479] Trial 238 finished with values: [0.32220709666657504, 0.0024727139445107627] and parameters: {'bagging_temperature': 0.2, 'border_count': 64, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.026872124688739455, 'random_strength': 40.0}.
# [I 2023-08-06 18:18:29,613] Trial 239 finished with values: [0.3236825007487318, 0.01960383752608502] and parameters: {'bagging_temperature': 0.4, 'border_count': 44, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.6, 'learning_rate': 0.0307933265079735, 'random_strength': 30.0}.
# [I 2023-08-06 18:18:35,118] Trial 240 finished with values: [0.29480236511797325, -0.006726944494681419] and parameters: {'bagging_temperature': 0.5, 'border_count': 44, 'depth': 4, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02463664142531081, 'random_strength': 30.0}.
# [I 2023-08-06 18:18:40,231] Trial 241 finished with values: [0.34777892812165057, 0.05237262385301289] and parameters: {'bagging_temperature': 0.4, 'border_count': 69, 'depth': 3, 'iterations': 600, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03783230534959908, 'random_strength': 35.0}.
# [I 2023-08-06 18:18:44,908] Trial 242 finished with values: [0.3232885703309642, -0.017635338833329184] and parameters: {'bagging_temperature': 0.4, 'border_count': 69, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.0339987864690301, 'random_strength': 35.0}.
# [I 2023-08-06 18:18:51,190] Trial 243 finished with values: [0.26744211359430753, -0.01679973749660829] and parameters: {'bagging_temperature': 0.0, 'border_count': 44, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02777391023671561, 'random_strength': 50.0}.
# [I 2023-08-06 18:18:56,593] Trial 244 finished with values: [0.36364141105737974, 0.02426425138536259] and parameters: {'bagging_temperature': 0.0, 'border_count': 6, 'depth': 4, 'iterations': 600, 'l2_leaf_reg': 5.4, 'learning_rate': 0.03783230534959908, 'random_strength': 30.0}.
# [I 2023-08-06 18:19:03,030] Trial 245 finished with values: [0.3010626132117718, -0.002599242593825768] and parameters: {'bagging_temperature': 0.2, 'border_count': 64, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.02293813262876192, 'random_strength': 40.0}.
# [I 2023-08-06 18:19:08,192] Trial 246 finished with values: [0.28019801368945435, -0.04448580173487299] and parameters: {'bagging_temperature': 0.0, 'border_count': 6, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.02601138912589874, 'random_strength': 60.0}.
# [I 2023-08-06 18:19:13,574] Trial 247 finished with values: [0.4180501099677305, 0.09654957033795897] and parameters: {'bagging_temperature': 0.2, 'border_count': 54, 'depth': 3, 'iterations': 650, 'l2_leaf_reg': 5.0, 'learning_rate': 0.048228907942629205, 'random_strength': 40.0}.
# [I 2023-08-06 18:19:18,449] Trial 248 finished with values: [0.3276487649809068, 0.03564714992486312] and parameters: {'bagging_temperature': 0.4, 'border_count': 31, 'depth': 3, 'iterations': 550, 'l2_leaf_reg': 5.3, 'learning_rate': 0.0339987864690301, 'random_strength': 65.0}.
# [I 2023-08-06 18:19:24,701] Trial 249 finished with values: [0.27616363446011727, -0.016855090332025202] and parameters: {'bagging_temperature': 0.1, 'border_count': 52, 'depth': 4, 'iterations': 650, 'l2_leaf_reg': 5.3, 'learning_rate': 0.0339987864690301, 'random_strength': 35.0}.
