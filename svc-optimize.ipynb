# %%
from pathlib import Path
import optuna
from fastai.tabular.core import cont_cat_split
import pandas as pd
from sklearn import compose, impute, pipeline, preprocessing, model_selection, svm
import numpy as np
from sklearn import metrics
from catboost import CatBoostClassifier

path = Path("./data")
output_path = Path("./output")

# %%
def balanced_log_loss(y_true, y_pred):
    nc = np.bincount(y_true)
    return metrics.log_loss(y_true, y_pred, sample_weight=1 / nc[y_true], eps=1e-15)

# %%
from collections import defaultdict

import numpy as np
import pandas as pd
from scipy import stats
from sklearn import compose, ensemble, impute, pipeline, preprocessing, tree

def get_preprocess_pipeline(df, cont_cols, cat_cols, drop_cols):
    """
    Returns a pipeline that performs the following transformations:
    * Standard scaling
    * Log transformation
    * Reciprocal transformation
    * Box-Cox transformation
    * Yeo-Johnson transformation
    * Categorical imputing
    * Semi-constant feature binarization

    Based on the EDA from https://www.kaggle.com/code/mateuszk013/icr-eda-balanced-learning-with-lgbm-xgb/notebook

    :param df: The dataframe to be transformed.
    :type df: pandas.DataFrame
    :param cont_names: The names of the continuous variables.
    :type cont_names: list of str
    :param dep_vars: The names of the dependent variables.
    :type dep_vars: list of str
    """

    # Identify columns that doesn't follow a normal distribution
    # find an appropriate transformation for them to follow a normal distribution
    r2_scores = defaultdict(tuple)

    for feature in cont_cols:
        orig = df[feature].dropna()
        _, (*_, R_orig) = stats.probplot(orig, rvalue=True)
        _, (*_, R_log) = stats.probplot(np.log(orig), rvalue=True)
        _, (*_, R_sqrt) = stats.probplot(np.sqrt(orig), rvalue=True)
        _, (*_, R_reci) = stats.probplot(np.reciprocal(orig), rvalue=True)
        _, (*_, R_boxcox) = stats.probplot(stats.boxcox(orig)[0], rvalue=True)
        _, (*_, R_yeojohn) = stats.probplot(stats.yeojohnson(orig)[0], rvalue=True)
        r2_scores[feature] = (
            R_orig * R_orig,
            R_log * R_log,
            R_sqrt * R_sqrt,
            R_reci * R_reci,
            R_boxcox * R_boxcox,
            R_yeojohn * R_yeojohn,
        )

    r2_scores = pd.DataFrame(
        r2_scores,
        index=("Original", "Log", "Sqrt", "Reciprocal", "BoxCox", "YeoJohnson"),
    ).T

    r2_scores["Winner"] = r2_scores.idxmax(axis=1)

    # Identify columns to be transformed
    no_transform_cols = r2_scores.query("Winner == 'Original'").index
    log_transform_cols = r2_scores.query("Winner == 'Log'").index
    reciprocal_transform_cols = r2_scores.query("Winner == 'Reciprocal'").index
    boxcox_transform_cols = r2_scores.query("Winner == 'BoxCox'").index
    yeojohnson_transform_cols = r2_scores.query("Winner == 'YeoJohnson'").index

    # Identify columns that are constant or semi-constant
    numeric_descr = df.drop(columns=drop_cols).describe().T
    semi_constant_mask = np.isclose(numeric_descr["min"], numeric_descr["50%"])
    semi_constant_descr = numeric_descr[semi_constant_mask]
    semi_const_cols_thresholds = semi_constant_descr["50%"].to_dict()

    # List of columns to be transformed
    semi_const_cols = semi_const_cols_thresholds.keys()
    no_transform_cols = no_transform_cols.drop(semi_const_cols, errors="ignore").to_list()
    log_transform_cols = log_transform_cols.drop(semi_const_cols, errors="ignore").to_list()
    reciprocal_transform_cols = reciprocal_transform_cols.drop(semi_const_cols, errors="ignore").to_list()
    boxcox_transform_cols = boxcox_transform_cols.drop(semi_const_cols, errors="ignore").to_list()
    yeojohnson_transform_cols = yeojohnson_transform_cols.drop(semi_const_cols, errors="ignore").to_list()

    # Transformations
    standard_scaling = (
        preprocessing.StandardScaler(),
        no_transform_cols,
    )
    log_transform = (
        pipeline.make_pipeline(
            preprocessing.FunctionTransformer(func=np.log, feature_names_out="one-to-one"),
            preprocessing.StandardScaler(),
        ),
        log_transform_cols,
    )
    reciprocal_transform = (
        pipeline.make_pipeline(
            preprocessing.FunctionTransformer(func=np.reciprocal, feature_names_out="one-to-one"),
            preprocessing.StandardScaler(),
        ),
        reciprocal_transform_cols,
    )
    boxcox_transform = (
        preprocessing.PowerTransformer(method="box-cox", standardize=True),
        boxcox_transform_cols,
    )
    yeojohnson_transform = (
        preprocessing.PowerTransformer(method="yeo-johnson", standardize=True),
        yeojohnson_transform_cols,
    )

    # Other transformations
    categorical_imputing = (
        pipeline.make_pipeline(
            impute.SimpleImputer(strategy="most_frequent"),
            preprocessing.OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1),
        ),
        cat_cols,  # type: ignore
    )
    semi_const_transforms = [
        (
            pipeline.make_pipeline(
                impute.SimpleImputer(strategy="median"),
                preprocessing.Binarizer(threshold=thresh),
            ),
            [col],
        )
        for col, thresh in semi_const_cols_thresholds.items()
    ]

    return pipeline.make_pipeline(
        compose.make_column_transformer(
            standard_scaling,
            log_transform,
            reciprocal_transform,
            boxcox_transform,
            yeojohnson_transform,
            categorical_imputing,
            *semi_const_transforms,
            remainder="drop",
            verbose_feature_names_out=False,
        ),
        impute.KNNImputer(n_neighbors=10, weights="distance"),
    ).set_output(transform="pandas")

    
# Load data
    
df = pd.read_csv(path / "train.csv", index_col="Id")
dep_vars = ["Class"]

drop_vars = ["EJ"]
df.drop(columns=drop_vars, inplace=True)

train_df, test_df = model_selection.train_test_split(df, test_size=0.4, stratify=df[dep_vars], random_state=33)


# Preprocess training data
# Drops the dep_vars before splitting categorical and continuous variables
cont_names, cat_names = cont_cat_split(train_df, dep_var=dep_vars)

preprocessor = get_preprocess_pipeline(train_df, cont_names, cat_names, dep_vars)

X_pre = preprocessor.fit_transform(train_df.drop(columns=dep_vars))
train_df = pd.merge(X_pre, train_df[dep_vars], left_index=True, right_index=True)
X = train_df.drop(columns=dep_vars, errors="ignore")
y = train_df[dep_vars]

# Preprocess test data
X_test_pre = preprocessor.transform(test_df.drop(columns=dep_vars))
test_df = pd.merge(X_test_pre, test_df[dep_vars], left_index=True, right_index=True)
X_test = test_df.drop(columns=dep_vars, errors="ignore")
y_test = test_df[dep_vars]

# %%
# Resample
from imblearn.over_sampling import SMOTE


def resample(X, y):
    sampler = SMOTE()
    X_res, y_res = sampler.fit_resample(X, y)
    return X_res, y_res

# %% [markdown]
# # Optimize

# %%
def objective(trial):
    params = dict(
        probability=True,
        C = trial.suggest_float('C', 0.01, 10),
        degree = trial.suggest_int('degree', 1, 10),
        gamma = trial.suggest_float('gamma', 0.01, 10),
        kernel=trial.suggest_categorical("kernel", ["linear", "poly", "rbf", "sigmoid"]),
    )
    
    if params['kernel'] in ['poly', 'sigmoid']:
        params["coef0"] = trial.suggest_float("coef0", 0.0, 10.0)

    model = svm.SVC(**params)

    skf = model_selection.RepeatedStratifiedKFold(n_splits=5, n_repeats=2)

    val_loss_list = []

    for i, (train_idx, val_idx) in enumerate(skf.split(X, y)):
        X_train = X.iloc[train_idx]
        y_train = y.iloc[train_idx].values.ravel()

        X_val = X.iloc[val_idx]
        y_val = y.iloc[val_idx].values.ravel()

        X_res, y_res = resample(X_train, y_train)
        model.fit(X_res, y_res)
        # model.fit(X_train, y_train)

        val_preds = model.predict_proba(X_val)
        val_loss = balanced_log_loss(y_val, val_preds)

        val_loss_list.append(val_loss)

    test_preds = model.predict_proba(X_test)
    test_loss = balanced_log_loss(y_test.values.ravel(), test_preds)
    mean_val_loss = np.mean(val_loss_list)

    return test_loss, test_loss - mean_val_loss

# %%
# optuna.delete_study(
#     study_name="svc_no_categorical_no_resample",
#     storage="sqlite:///optuna.db",
# )

# %%
pruner = optuna.pruners.SuccessiveHalvingPruner()
study = optuna.create_study(
    pruner=pruner,
    directions=["minimize", "minimize"],
    study_name="svc_no_categorical_resample",
    storage="sqlite:///optuna.db",
    load_if_exists=True,
)
study.optimize(objective, n_trials=250)
# Out:
# [I 2023-08-06 17:19:55,495] A new study created in RDB with name: svc_no_categorical_resample
# [I 2023-08-06 17:19:56,114] Trial 0 finished with values: [0.6725850310117728, 0.009931786136960219] and parameters: {'C': 0.898187725414952, 'coef0': 2.0042487222149274, 'degree': 7, 'gamma': 8.662658767168917, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:19:56,425] Trial 1 finished with values: [0.505563423310618, -0.37102951608655144] and parameters: {'C': 0.10494454342481872, 'coef0': 3.824904866977622, 'degree': 1, 'gamma': 4.562122187849798, 'kernel': 'poly'}.
# [I 2023-08-06 17:19:56,823] Trial 2 finished with values: [0.6657863986069901, -0.02320919231636509] and parameters: {'C': 7.4924833558803865, 'coef0': 1.6181052812431074, 'degree': 7, 'gamma': 2.6020038915210386, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:19:57,732] Trial 3 finished with values: [0.6543614106423866, -0.07032984743994786] and parameters: {'C': 8.71605916180572, 'degree': 7, 'gamma': 0.7503847122734622, 'kernel': 'linear'}.
# [I 2023-08-06 17:19:58,385] Trial 4 finished with values: [0.7238561519281445, -0.029356552337680974] and parameters: {'C': 2.2294511652853295, 'degree': 8, 'gamma': 4.222929761828418, 'kernel': 'rbf'}.
# [I 2023-08-06 17:19:59,049] Trial 5 finished with values: [0.8125340466713489, 0.005567772087973544] and parameters: {'C': 2.2708543321276813, 'degree': 10, 'gamma': 2.19282463131809, 'kernel': 'rbf'}.
# [I 2023-08-06 17:19:59,551] Trial 6 finished with values: [0.6108492346113242, -0.2260582329408446] and parameters: {'C': 2.2557021449241383, 'degree': 4, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:00,280] Trial 7 finished with values: [0.7225043346085339, -0.017439692270241447] and parameters: {'C': 4.452341774183273, 'degree': 3, 'gamma': 4.752492728592623, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:00,961] Trial 8 finished with values: [0.9274157819491352, -0.02091408396635841] and parameters: {'C': 1.736269855710491, 'degree': 5, 'gamma': 1.1852549782599797, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:01,618] Trial 9 finished with values: [0.7927532409158065, 0.04311275000499737] and parameters: {'C': 3.4578956249386197, 'degree': 7, 'gamma': 4.9424016879240185, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:02,258] Trial 10 finished with values: [0.7665002811787862, -0.006675373182286504] and parameters: {'C': 3.14762251762083, 'degree': 8, 'gamma': 3.4748581836487165, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:02,963] Trial 11 finished with values: [0.708558720999082, -0.0095410609675044] and parameters: {'C': 1.3376955947047011, 'degree': 6, 'gamma': 7.213019369846754, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:03,593] Trial 12 finished with values: [0.7802795574496455, -0.06443466958124644] and parameters: {'C': 3.955511826281674, 'degree': 2, 'gamma': 2.0448106493613523, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:04,247] Trial 13 finished with values: [0.5691023993640634, -0.18756063779073762] and parameters: {'C': 6.0220026727620235, 'degree': 4, 'gamma': 1.6830744649424811, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:04,682] Trial 14 finished with values: [1.0451972495598638, -0.05620856937261465] and parameters: {'C': 4.0079700865677355, 'coef0': 8.009593700040234, 'degree': 7, 'gamma': 5.354561305359376, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:05,119] Trial 15 finished with values: [0.628779441477319, -0.07203570174106244] and parameters: {'C': 1.1415112927492717, 'coef0': 8.77236005761014, 'degree': 5, 'gamma': 2.659739054948988, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:05,521] Trial 16 finished with values: [0.6846208230033991, 0.01027968937590007] and parameters: {'C': 7.142077307059982, 'coef0': 9.518816229163068, 'degree': 3, 'gamma': 8.960384669601991, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:06,198] Trial 17 finished with values: [1.62948885194296, -0.22102800752737783] and parameters: {'C': 6.843148138142914, 'degree': 4, 'gamma': 0.15175168626337207, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:06,554] Trial 18 finished with values: [0.662948374754835, 0.00022057299104627504] and parameters: {'C': 6.878271736938086, 'coef0': 2.3292863776348893, 'degree': 2, 'gamma': 6.492321092454662, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:07,435] Trial 19 finished with values: [0.47714722630601736, -0.486071274500698] and parameters: {'C': 7.984554287093118, 'degree': 9, 'gamma': 8.422337446790786, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:08,281] Trial 20 finished with values: [0.9724422101532703, 0.21795118229392563] and parameters: {'C': 9.875758801125226, 'degree': 2, 'gamma': 5.207675860978821, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:08,827] Trial 21 finished with values: [0.7131739446393219, -0.08997714981953919] and parameters: {'C': 2.480676551727514, 'degree': 10, 'gamma': 4.512259730482913, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:09,291] Trial 22 finished with values: [0.9632669155677068, -0.03436978649819167] and parameters: {'C': 1.613556603075072, 'coef0': 8.663781517132321, 'degree': 5, 'gamma': 4.8744731084141915, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:09,973] Trial 23 finished with values: [0.7338440279264508, 0.012161272039283966] and parameters: {'C': 2.1432655928676976, 'degree': 7, 'gamma': 6.065354938133936, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:10,888] Trial 24 finished with values: [0.7011843547668856, -0.015094630300479195] and parameters: {'C': 4.011467609876467, 'degree': 7, 'gamma': 8.984412203425189, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:11,648] Trial 25 finished with values: [0.7310148300727336, 0.01509758602590272] and parameters: {'C': 6.427326534612916, 'degree': 8, 'gamma': 7.910502824242035, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:12,731] Trial 26 finished with values: [0.7111180633655001, -0.010329779653476368] and parameters: {'C': 7.397153825133207, 'degree': 3, 'gamma': 7.930004966999463, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:13,241] Trial 27 finished with values: [1.4032424080815014, 0.23458698905684794] and parameters: {'C': 1.0442384423496998, 'coef0': 5.251281567516621, 'degree': 10, 'gamma': 8.551677387844544, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:13,915] Trial 28 finished with values: [0.7892814500642276, 0.05094927661108761] and parameters: {'C': 6.959468075509921, 'degree': 3, 'gamma': 5.089098115273968, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:14,592] Trial 29 finished with values: [0.7243797485845308, 0.0025432390335436983] and parameters: {'C': 3.7741819189601147, 'degree': 6, 'gamma': 4.9925968928842215, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:15,284] Trial 30 finished with values: [0.7979935614268359, 0.030273138728370785] and parameters: {'C': 3.0281433035205367, 'degree': 1, 'gamma': 2.7644194630344794, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:15,730] Trial 31 finished with values: [1.4821371901645344, 0.34135820416153506] and parameters: {'C': 2.2318249820058185, 'coef0': 7.456728296734562, 'degree': 10, 'gamma': 7.466426174409562, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:16,154] Trial 32 finished with values: [1.7227793734266028, 0.13877656431491192] and parameters: {'C': 5.266787424572269, 'coef0': 5.388484010056879, 'degree': 6, 'gamma': 8.502545923242531, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:16,470] Trial 33 finished with values: [0.6586666314133826, -0.01786701943990321] and parameters: {'C': 9.170964322047395, 'coef0': 6.252389554621482, 'degree': 6, 'gamma': 9.688651132864052, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:16,731] Trial 34 finished with values: [0.9104067804642786, 0.2887282240454958] and parameters: {'C': 0.40840908696559963, 'degree': 1, 'gamma': 0.8257430805031918, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:17,422] Trial 35 finished with values: [0.7098926253437546, -0.007978800438581901] and parameters: {'C': 5.286054098595907, 'degree': 8, 'gamma': 6.715365403123928, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:17,832] Trial 36 finished with values: [0.9248389985048495, 0.042165801139988246] and parameters: {'C': 9.431820426337586, 'coef0': 3.325712453943026, 'degree': 5, 'gamma': 2.794560017027071, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:18,259] Trial 37 finished with values: [1.1941950885823307, 0.1269822121384252] and parameters: {'C': 8.292011881666491, 'coef0': 8.380919798311695, 'degree': 7, 'gamma': 9.505031363414506, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:19,083] Trial 38 finished with values: [0.5577175532534392, -0.3280736631986665] and parameters: {'C': 8.483572584797336, 'degree': 10, 'gamma': 4.359531446008861, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:19,464] Trial 39 finished with values: [0.698493666313931, 0.017653986889393458] and parameters: {'C': 9.808848512078663, 'coef0': 2.8096796969140136, 'degree': 5, 'gamma': 1.6930612007078567, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:19,854] Trial 40 finished with values: [0.6557646031271315, -0.02520002138421429] and parameters: {'C': 4.370533469813985, 'coef0': 2.74978365117852, 'degree': 9, 'gamma': 2.10089265458446, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:20,081] Trial 41 finished with values: [0.6288624210828689, 0.10946039139404518] and parameters: {'C': 0.04262518869877446, 'coef0': 5.919757353781645, 'degree': 1, 'gamma': 1.6789499119244022, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:20,810] Trial 42 finished with values: [0.7422677843961292, -0.0034909722404531385] and parameters: {'C': 9.383739701057353, 'degree': 7, 'gamma': 4.574996245525265, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:21,556] Trial 43 finished with values: [0.5037752945052288, -0.24938804118870872] and parameters: {'C': 7.408557264582804, 'degree': 4, 'gamma': 6.221114490339412, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:22,138] Trial 44 finished with values: [0.8554598594749259, 0.18308246543135875] and parameters: {'C': 3.9923763869321656, 'degree': 2, 'gamma': 2.5308257073884985, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:22,560] Trial 45 finished with values: [0.835729481518471, 0.009147913430485488] and parameters: {'C': 8.40838471306979, 'coef0': 3.262560355857361, 'degree': 5, 'gamma': 9.97164762330044, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:24,680] Trial 46 finished with values: [0.5484342382091384, -0.3284004824451018] and parameters: {'C': 4.866923759646295, 'coef0': 8.616056350730844, 'degree': 1, 'gamma': 8.52180691393, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:25,355] Trial 47 finished with values: [1.1269831418110559, 0.09435197900007353] and parameters: {'C': 3.491197110309898, 'degree': 9, 'gamma': 1.1187936972414148, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:26,413] Trial 48 finished with values: [0.5930716521734851, -0.2240111898546019] and parameters: {'C': 7.528318185397283, 'degree': 7, 'gamma': 4.43017740432043, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:26,787] Trial 49 finished with values: [0.6802633120890972, -0.008868450445401854] and parameters: {'C': 2.2708444545699926, 'coef0': 4.198388458542838, 'degree': 3, 'gamma': 1.788856891744364, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:27,134] Trial 50 finished with values: [0.6595854856062545, -0.018672274717097204] and parameters: {'C': 8.637039442660345, 'coef0': 6.158059651968262, 'degree': 1, 'gamma': 5.141264404730492, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:27,900] Trial 51 finished with values: [0.7754835766789955, 0.03820344727413938] and parameters: {'C': 7.984554287093118, 'degree': 5, 'gamma': 0.24524527811036503, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:28,546] Trial 52 finished with values: [0.8382564078277518, 0.015505685704451655] and parameters: {'C': 2.2708444545699926, 'degree': 9, 'gamma': 2.10089265458446, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:29,659] Trial 53 finished with values: [0.4989964452215446, -0.11619603349677254] and parameters: {'C': 9.170964322047395, 'degree': 6, 'gamma': 8.422337446790786, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:30,055] Trial 54 finished with values: [0.6772842247361842, -0.026252944078770324] and parameters: {'C': 2.480676551727514, 'coef0': 9.308545883576013, 'degree': 5, 'gamma': 2.6020038915210386, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:30,766] Trial 55 finished with values: [0.7229456499828922, -0.010255231461135272] and parameters: {'C': 2.900978701566536, 'degree': 2, 'gamma': 4.222929761828418, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:31,190] Trial 56 finished with values: [1.483466384077924, 0.28026929432914005] and parameters: {'C': 2.2557021449241383, 'coef0': 2.461121382768029, 'degree': 4, 'gamma': 5.028169341748529, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:32,031] Trial 57 finished with values: [0.4879018102714182, -0.2702357463477493] and parameters: {'C': 7.9451838348558175, 'degree': 3, 'gamma': 4.43017740432043, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:32,672] Trial 58 finished with values: [0.872628874047233, 0.0030859707215618037] and parameters: {'C': 4.7851201574585955, 'degree': 3, 'gamma': 1.788856891744364, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:33,401] Trial 59 finished with values: [0.7174448161072461, 0.008876924348538595] and parameters: {'C': 0.898187725414952, 'degree': 7, 'gamma': 7.213019369846754, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:34,193] Trial 60 finished with values: [0.5361971234332639, -0.16836873422758358] and parameters: {'C': 7.528318185397283, 'degree': 8, 'gamma': 3.4748581836487165, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:34,642] Trial 61 finished with values: [0.9720592943649695, 0.011283797873267831] and parameters: {'C': 2.2708444545699926, 'coef0': 5.646137558126554, 'degree': 9, 'gamma': 7.178016494936147, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:35,347] Trial 62 finished with values: [0.8777158841343328, 0.03874859146552745] and parameters: {'C': 4.187233425497353, 'degree': 8, 'gamma': 2.226176686017115, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:35,815] Trial 63 finished with values: [0.5400486513331171, -0.10936545168839884] and parameters: {'C': 2.480676551727514, 'degree': 10, 'gamma': 4.359531446008861, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:36,302] Trial 64 finished with values: [0.6692388814408983, -0.00913039407014038] and parameters: {'C': 9.170964322047395, 'coef0': 9.127965868099624, 'degree': 6, 'gamma': 9.688651132864052, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:36,938] Trial 65 finished with values: [0.6936721924435633, -0.028465756002928222] and parameters: {'C': 4.370533469813985, 'degree': 2, 'gamma': 2.5308257073884985, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:37,284] Trial 66 finished with values: [0.6756114600596855, -0.004338348375093837] and parameters: {'C': 7.142077307059982, 'coef0': 6.787989665827407, 'degree': 9, 'gamma': 5.436858598796181, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:37,608] Trial 67 finished with values: [0.6906007587024479, 0.01921758426636555] and parameters: {'C': 0.898187725414952, 'coef0': 1.8767959377558563, 'degree': 7, 'gamma': 8.662658767168917, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:38,041] Trial 68 finished with values: [1.479306564490176, 0.2777445969387793] and parameters: {'C': 8.895236209684755, 'coef0': 8.748140781148804, 'degree': 7, 'gamma': 2.5308257073884985, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:38,752] Trial 69 finished with values: [0.7676426344508129, 0.05096515046219485] and parameters: {'C': 1.9950638909090677, 'degree': 8, 'gamma': 7.482793644328289, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:39,594] Trial 70 finished with values: [0.734318800796245, 0.11281867891639574] and parameters: {'C': 7.984554287093118, 'degree': 3, 'gamma': 1.1029048885756394, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:40,039] Trial 71 finished with values: [1.8027987829685346, 0.43223989663908036] and parameters: {'C': 2.2318249820058185, 'coef0': 3.235698240328256, 'degree': 10, 'gamma': 7.466426174409562, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:40,704] Trial 72 finished with values: [0.7704409731578776, -0.014764937653833798] and parameters: {'C': 6.959468075509921, 'degree': 2, 'gamma': 2.5308257073884985, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:41,369] Trial 73 finished with values: [0.9931923860403513, 0.02376155196291807] and parameters: {'C': 3.491197110309898, 'degree': 9, 'gamma': 1.1187936972414148, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:41,691] Trial 74 finished with values: [0.6933950679260726, 0.012998479847661781] and parameters: {'C': 2.2294511652853295, 'coef0': 0.7292880235163812, 'degree': 7, 'gamma': 7.8158544833747845, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:42,063] Trial 75 finished with values: [0.7824684402277631, -0.14351514068809523] and parameters: {'C': 9.028681720820531, 'coef0': 0.4326728199062435, 'degree': 3, 'gamma': 6.143512644842968, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:42,511] Trial 76 finished with values: [0.5857098830314764, -0.11491912660361536] and parameters: {'C': 2.1432655928676976, 'degree': 2, 'gamma': 8.554506392100107, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:43,259] Trial 77 finished with values: [0.7054296723796651, -0.008016659390214786] and parameters: {'C': 9.383739701057353, 'degree': 7, 'gamma': 8.422337446790786, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:44,072] Trial 78 finished with values: [1.0059703068640133, 0.28312009656673676] and parameters: {'C': 7.984554287093118, 'degree': 1, 'gamma': 8.422337446790786, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:45,252] Trial 79 finished with values: [0.7501235337610261, -0.04688231565002232] and parameters: {'C': 2.2557021449241383, 'coef0': 6.673271516590332, 'degree': 1, 'gamma': 5.028169341748529, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:45,676] Trial 80 finished with values: [0.9379162291232084, -0.05728632864785854] and parameters: {'C': 1.613556603075072, 'coef0': 1.8271695481922312, 'degree': 7, 'gamma': 3.3086805074271863, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:46,075] Trial 81 finished with values: [0.6971600771404317, -0.011542343038298819] and parameters: {'C': 4.370533469813985, 'coef0': 8.902606302890131, 'degree': 5, 'gamma': 2.10089265458446, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:46,785] Trial 82 finished with values: [0.7352158177560159, 0.012100082204090534] and parameters: {'C': 4.866923759646295, 'degree': 8, 'gamma': 6.715365403123928, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:47,485] Trial 83 finished with values: [0.8108796562534408, 0.06480332456755411] and parameters: {'C': 2.2557021449241383, 'degree': 4, 'gamma': 5.028169341748529, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:47,926] Trial 84 finished with values: [0.5160339262184684, -0.26040523744225363] and parameters: {'C': 2.480676551727514, 'degree': 6, 'gamma': 4.687509227433365, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:48,564] Trial 85 finished with values: [0.8110032479963721, -0.040560085565453985] and parameters: {'C': 3.0281433035205367, 'degree': 1, 'gamma': 1.6830744649424811, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:48,986] Trial 86 finished with values: [0.6839516879687072, 0.008278496905278154] and parameters: {'C': 4.370533469813985, 'coef0': 0.6862172196129657, 'degree': 8, 'gamma': 2.10089265458446, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:49,259] Trial 87 finished with values: [0.5028114055022751, -0.18916153869352825] and parameters: {'C': 0.40840908696559963, 'degree': 1, 'gamma': 5.403563277187749, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:49,931] Trial 88 finished with values: [0.7768223281375664, 0.024618089707186264] and parameters: {'C': 4.011467609876467, 'degree': 8, 'gamma': 3.4748581836487165, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:50,691] Trial 89 finished with values: [0.7042901382426214, -0.016257469737631425] and parameters: {'C': 1.736269855710491, 'degree': 8, 'gamma': 7.930004966999463, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:51,114] Trial 90 finished with values: [0.6733298826081315, -0.01802106485922983] and parameters: {'C': 2.480676551727514, 'coef0': 6.548640153634815, 'degree': 10, 'gamma': 4.512259730482913, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:51,988] Trial 91 finished with values: [0.5930094050546569, -0.28204835524943184] and parameters: {'C': 9.875758801125226, 'degree': 9, 'gamma': 5.207675860978821, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:52,467] Trial 92 finished with values: [0.522536915418536, -0.17172778196294403] and parameters: {'C': 2.2557021449241383, 'degree': 9, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:53,222] Trial 93 finished with values: [0.5884451455398462, -0.16245982559096717] and parameters: {'C': 8.483572584797336, 'degree': 9, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:53,865] Trial 94 finished with values: [0.5555360111816839, -0.18077996886694236] and parameters: {'C': 4.835080145334154, 'degree': 6, 'gamma': 5.760061383659807, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:54,249] Trial 95 finished with values: [0.6660927273790612, -0.0306542906559506] and parameters: {'C': 9.808848512078663, 'coef0': 5.303687989028642, 'degree': 5, 'gamma': 1.6930612007078567, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:54,633] Trial 96 finished with values: [0.7063585356734111, 0.0043288997984126665] and parameters: {'C': 6.0220026727620235, 'coef0': 8.815134532813984, 'degree': 3, 'gamma': 1.6830744649424811, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:55,260] Trial 97 finished with values: [0.6931471805599453, -0.0003224586055855516] and parameters: {'C': 0.10494454342481872, 'degree': 1, 'gamma': 4.562122187849798, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:55,650] Trial 98 finished with values: [0.6886162651032951, 0.00034671580436584915] and parameters: {'C': 7.4924833558803865, 'coef0': 5.979448629373491, 'degree': 5, 'gamma': 2.6020038915210386, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:56,031] Trial 99 finished with values: [0.6798521390551499, -0.005511859806601627] and parameters: {'C': 7.142077307059982, 'coef0': 3.2624227866060576, 'degree': 1, 'gamma': 1.5155652974042988, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:56,767] Trial 100 finished with values: [0.812589791263442, 0.06373290977410873] and parameters: {'C': 4.370533469813985, 'degree': 8, 'gamma': 3.976960192124069, 'kernel': 'rbf'}.
# [I 2023-08-06 17:20:57,116] Trial 101 finished with values: [0.6465178084154048, -0.02720688900014745] and parameters: {'C': 6.861132389949674, 'coef0': 0.19709502036909687, 'degree': 2, 'gamma': 5.028169341748529, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:57,474] Trial 102 finished with values: [0.6945012873423151, -0.01308311571850651] and parameters: {'C': 4.011467609876467, 'coef0': 8.603827456680397, 'degree': 4, 'gamma': 0.8179949587296685, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:20:57,914] Trial 103 finished with values: [1.1882937786990282, 0.2172244222310573] and parameters: {'C': 2.2557021449241383, 'coef0': 7.073041039344782, 'degree': 9, 'gamma': 4.450977134916969, 'kernel': 'poly'}.
# [I 2023-08-06 17:20:58,745] Trial 104 finished with values: [0.6296287766433565, -0.006186755187347459] and parameters: {'C': 9.875758801125226, 'degree': 9, 'gamma': 0.30922910626793637, 'kernel': 'linear'}.
# [I 2023-08-06 17:20:59,271] Trial 105 finished with values: [0.6836148653716051, 0.0011579109698760526] and parameters: {'C': 1.4600732142353936, 'coef0': 5.472635126125076, 'degree': 3, 'gamma': 5.760061383659807, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:00,247] Trial 106 finished with values: [0.523863513919272, -0.3098610755565] and parameters: {'C': 9.028681720820531, 'degree': 9, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:01,029] Trial 107 finished with values: [0.4932887462492497, -0.2001547659195405] and parameters: {'C': 7.9451838348558175, 'degree': 3, 'gamma': 1.0716951169250413, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:01,469] Trial 108 finished with values: [1.1032313174729154, 0.013723412967804771] and parameters: {'C': 4.0079700865677355, 'coef0': 7.304730125262528, 'degree': 9, 'gamma': 5.354561305359376, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:02,419] Trial 109 finished with values: [0.6287104143409995, -0.1679887983347561] and parameters: {'C': 9.875758801125226, 'degree': 9, 'gamma': 5.207675860978821, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:03,146] Trial 110 finished with values: [0.5078020017609052, -0.12093321494679421] and parameters: {'C': 7.528318185397283, 'degree': 3, 'gamma': 4.43017740432043, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:03,878] Trial 111 finished with values: [0.621923613785446, -0.18895849011637034] and parameters: {'C': 7.22026446037536, 'degree': 1, 'gamma': 3.044180673421067, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:04,524] Trial 112 finished with values: [0.8033620067358852, 0.0641207960068878] and parameters: {'C': 4.452341774183273, 'degree': 9, 'gamma': 4.752492728592623, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:04,887] Trial 113 finished with values: [0.6327381477473003, -0.05860331560267973] and parameters: {'C': 1.1415112927492717, 'coef0': 1.6263587890717635, 'degree': 5, 'gamma': 4.549737359055177, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:05,694] Trial 114 finished with values: [0.6484069359445254, -0.03067867501375543] and parameters: {'C': 7.528318185397283, 'degree': 9, 'gamma': 8.652287138910847, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:06,064] Trial 115 finished with values: [0.6335217281369446, -0.0426042342699372] and parameters: {'C': 2.480676551727514, 'coef0': 2.0848131607661626, 'degree': 5, 'gamma': 4.512259730482913, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:06,801] Trial 116 finished with values: [0.7042596441113428, -0.010643362924956157] and parameters: {'C': 7.658014251850701, 'degree': 8, 'gamma': 8.984412203425189, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:07,615] Trial 117 finished with values: [0.5790271807712052, -0.21145371638892152] and parameters: {'C': 6.3212596485493275, 'degree': 9, 'gamma': 4.359531446008861, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:08,437] Trial 118 finished with values: [0.6904830466222833, -0.04281959669822477] and parameters: {'C': 8.483572584797336, 'degree': 10, 'gamma': 7.415786031604752, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:09,091] Trial 119 finished with values: [0.6034958695994973, -0.11186954910561575] and parameters: {'C': 4.835080145334154, 'degree': 7, 'gamma': 8.125315669138603, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:09,462] Trial 120 finished with values: [0.6729191427281701, -0.01423617244715758] and parameters: {'C': 9.808848512078663, 'coef0': 2.884468674635905, 'degree': 5, 'gamma': 1.6930612007078567, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:10,569] Trial 121 finished with values: [0.8480603547145524, 0.06488264485122253] and parameters: {'C': 2.2557021449241383, 'coef0': 3.7225974447476884, 'degree': 1, 'gamma': 5.436858598796181, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:11,253] Trial 122 finished with values: [0.7621735720346302, 0.023158595776766933] and parameters: {'C': 3.3361227784860383, 'degree': 9, 'gamma': 5.028169341748529, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:11,703] Trial 123 finished with values: [1.2250320641595425, 0.004283189857104297] and parameters: {'C': 5.726883844085984, 'coef0': 0.04319317360926611, 'degree': 10, 'gamma': 1.6830744649424811, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:12,516] Trial 124 finished with values: [0.7604399585902157, 0.2121500806707709] and parameters: {'C': 8.637039442660345, 'degree': 1, 'gamma': 5.545497566117684, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:13,039] Trial 125 finished with values: [0.7198339905473031, -0.03586051305862237] and parameters: {'C': 2.480676551727514, 'degree': 6, 'gamma': 4.43017740432043, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:13,494] Trial 126 finished with values: [0.633402281002918, -0.10369458387005825] and parameters: {'C': 2.1432655928676976, 'degree': 2, 'gamma': 8.554506392100107, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:13,896] Trial 127 finished with values: [0.6931223902049434, 0.0036908154934096604] and parameters: {'C': 7.4924833558803865, 'coef0': 6.0958442404640225, 'degree': 7, 'gamma': 2.6020038915210386, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:14,260] Trial 128 finished with values: [0.7084973156642833, 0.030700063092788277] and parameters: {'C': 7.528318185397283, 'coef0': 1.2323151519939912, 'degree': 10, 'gamma': 4.359531446008861, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:15,177] Trial 129 finished with values: [0.8572843680909923, 0.0614321195351919] and parameters: {'C': 1.1415112927492717, 'coef0': 0.5935245975870385, 'degree': 1, 'gamma': 8.52180691393, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:15,676] Trial 130 finished with values: [0.6707860243941918, -0.116945083408737] and parameters: {'C': 3.0288270710625356, 'degree': 1, 'gamma': 5.403563277187749, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:16,154] Trial 131 finished with values: [0.5965120479219285, -0.10903918446525807] and parameters: {'C': 2.1432655928676976, 'degree': 2, 'gamma': 1.7187870723293517, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:16,587] Trial 132 finished with values: [1.4831306783442229, 0.402757574645479] and parameters: {'C': 2.2708444545699926, 'coef0': 2.9205666837269453, 'degree': 7, 'gamma': 1.788856891744364, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:17,303] Trial 133 finished with values: [0.7218843714226055, -0.002204308775902497] and parameters: {'C': 2.2557021449241383, 'degree': 4, 'gamma': 6.221114490339412, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:18,031] Trial 134 finished with values: [0.8938346033011637, 0.15469533845056294] and parameters: {'C': 6.681426256412413, 'degree': 10, 'gamma': 3.5059726767168096, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:18,637] Trial 135 finished with values: [1.6615615913167447, -0.16662422697907053] and parameters: {'C': 9.96606224811158, 'degree': 4, 'gamma': 0.15175168626337207, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:19,769] Trial 136 finished with values: [0.6376683582640311, -0.13983002480425388] and parameters: {'C': 7.528318185397283, 'degree': 8, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:20,298] Trial 137 finished with values: [0.7668817579654883, 0.05922604260905884] and parameters: {'C': 2.480676551727514, 'degree': 8, 'gamma': 4.687509227433365, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:20,753] Trial 138 finished with values: [1.1923301318330666, -0.17902723301686274] and parameters: {'C': 8.483572584797336, 'coef0': 2.630784085693226, 'degree': 10, 'gamma': 8.52180691393, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:21,119] Trial 139 finished with values: [0.9339200252465664, -0.05691543884496064] and parameters: {'C': 8.502582985696135, 'coef0': 6.5541286842106405, 'degree': 3, 'gamma': 9.318886045344533, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:21,745] Trial 140 finished with values: [1.814417959711709, -0.034269370849458136] and parameters: {'C': 6.843148138142914, 'degree': 4, 'gamma': 0.15175168626337207, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:23,298] Trial 141 finished with values: [0.9823464021809825, 0.22861015418656172] and parameters: {'C': 2.704443808257084, 'coef0': 3.8352556298341147, 'degree': 1, 'gamma': 8.52180691393, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:23,900] Trial 142 finished with values: [0.6391033346748033, -0.09696748576254899] and parameters: {'C': 4.452341774183273, 'degree': 3, 'gamma': 4.752492728592623, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:24,143] Trial 143 finished with values: [0.5580538444412818, -0.1607996694189494] and parameters: {'C': 0.10494454342481872, 'coef0': 1.2464370649551015, 'degree': 1, 'gamma': 2.6020038915210386, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:25,082] Trial 144 finished with values: [0.4816462123895763, -0.3271284299468096] and parameters: {'C': 8.055607770026281, 'degree': 3, 'gamma': 4.43017740432043, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:25,538] Trial 145 finished with values: [0.570553220243997, -0.1322484529117942] and parameters: {'C': 2.2557021449241383, 'degree': 9, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:26,139] Trial 146 finished with values: [0.556106203197405, -0.22150876357000915] and parameters: {'C': 4.866923759646295, 'degree': 1, 'gamma': 9.714313336416213, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:26,913] Trial 147 finished with values: [0.8285792309859898, 0.04107818487135839] and parameters: {'C': 8.483572584797336, 'degree': 7, 'gamma': 0.7503847122734622, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:27,228] Trial 148 finished with values: [0.6857938248927282, 0.006975365799239741] and parameters: {'C': 7.142077307059982, 'coef0': 7.237231719805454, 'degree': 3, 'gamma': 9.688651132864052, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:28,948] Trial 149 finished with values: [1.5921810420063396, 0.7649072589382498] and parameters: {'C': 9.951046182061816, 'coef0': 3.019997422054349, 'degree': 1, 'gamma': 4.562122187849798, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:29,764] Trial 150 finished with values: [0.5850013431423252, 0.017084369610500416] and parameters: {'C': 8.483572584797336, 'degree': 10, 'gamma': 4.359531446008861, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:30,153] Trial 151 finished with values: [1.029268854544963, 0.13368994506520948] and parameters: {'C': 6.0220026727620235, 'coef0': 5.294024311802007, 'degree': 4, 'gamma': 1.6830744649424811, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:30,926] Trial 152 finished with values: [0.7032850821241304, -0.006330925355000794] and parameters: {'C': 3.2997718193429617, 'degree': 1, 'gamma': 9.88537424556979, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:31,144] Trial 153 finished with values: [0.5746048045275277, 0.03733238294844321] and parameters: {'C': 0.037350502189183316, 'degree': 1, 'gamma': 0.15175168626337207, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:31,508] Trial 154 finished with values: [0.6856837687699933, -0.0024863658447873416] and parameters: {'C': 9.170964322047395, 'coef0': 9.395230982780365, 'degree': 6, 'gamma': 4.43017740432043, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:32,129] Trial 155 finished with values: [0.6335540565804951, -0.11816827478451875] and parameters: {'C': 4.452341774183273, 'degree': 8, 'gamma': 3.4748581836487165, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:33,144] Trial 156 finished with values: [0.6398695754890842, -0.10247013338122957] and parameters: {'C': 9.028681720820531, 'degree': 2, 'gamma': 3.5583526908443366, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:33,591] Trial 157 finished with values: [1.516808699247116, 0.21724897841011725] and parameters: {'C': 1.3470061372345254, 'coef0': 9.842051091223018, 'degree': 8, 'gamma': 4.562122187849798, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:34,343] Trial 158 finished with values: [0.5283968920691101, -0.17323771627291662] and parameters: {'C': 6.0220026727620235, 'degree': 9, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:35,090] Trial 159 finished with values: [0.7389063226024954, -0.07737181747851829] and parameters: {'C': 8.055607770026281, 'degree': 3, 'gamma': 1.0716951169250413, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:35,344] Trial 160 finished with values: [1.2641080512891594, 0.2201066840146071] and parameters: {'C': 6.657889415602199, 'coef0': 8.263589141886099, 'degree': 2, 'gamma': 4.359531446008861, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:35,564] Trial 161 finished with values: [0.5153478325381454, -0.06971300580547068] and parameters: {'C': 0.10494454342481872, 'degree': 8, 'gamma': 3.4748581836487165, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:36,353] Trial 162 finished with values: [0.7232573845180074, 0.005083704795255661] and parameters: {'C': 2.5112387828437024, 'degree': 1, 'gamma': 8.422337446790786, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:36,726] Trial 163 finished with values: [0.6696372498004747, -0.0031700306799911093] and parameters: {'C': 2.480676551727514, 'coef0': 0.4043165462223153, 'degree': 2, 'gamma': 4.512259730482913, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:37,196] Trial 164 finished with values: [1.4868850171262247, 0.298235184545639] and parameters: {'C': 4.592366602052714, 'coef0': 2.5187336034283057, 'degree': 10, 'gamma': 5.825072676771593, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:37,732] Trial 165 finished with values: [0.6501752513213624, -0.06668839018694905] and parameters: {'C': 3.308034150276356, 'degree': 2, 'gamma': 3.044180673421067, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:38,466] Trial 166 finished with values: [0.5160118268384328, -0.19661766024503513] and parameters: {'C': 7.408557264582804, 'degree': 4, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:38,904] Trial 167 finished with values: [0.8825865857732456, 0.10149124994297332] and parameters: {'C': 2.480676551727514, 'degree': 6, 'gamma': 6.221114490339412, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:39,671] Trial 168 finished with values: [0.7214805614416769, 0.00782515541292772] and parameters: {'C': 9.141020156641158, 'degree': 1, 'gamma': 9.714313336416213, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:40,262] Trial 169 finished with values: [0.6049564989411994, -0.11307288583690578] and parameters: {'C': 3.4500497824575014, 'degree': 2, 'gamma': 9.112551163294967, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:40,679] Trial 170 finished with values: [1.5151316996611746, 0.18774992786829414] and parameters: {'C': 5.220312783881447, 'coef0': 8.634446704864086, 'degree': 6, 'gamma': 5.028169341748529, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:41,165] Trial 171 finished with values: [0.5118343449946628, -0.171574843641494] and parameters: {'C': 1.7998428986581108, 'degree': 2, 'gamma': 8.554506392100107, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:41,973] Trial 172 finished with values: [0.8355442135248938, 0.14861199321726926] and parameters: {'C': 8.483572584797336, 'degree': 1, 'gamma': 4.359531446008861, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:42,438] Trial 173 finished with values: [0.6923687814250264, -0.10585263698382652] and parameters: {'C': 2.480676551727514, 'degree': 6, 'gamma': 0.30922910626793637, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:43,417] Trial 174 finished with values: [0.5657312084598738, -0.09874733407595426] and parameters: {'C': 9.028681720820531, 'degree': 3, 'gamma': 4.752492728592623, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:43,828] Trial 175 finished with values: [0.6997463689257833, -0.18052544341437882] and parameters: {'C': 9.028681720820531, 'coef0': 7.85781765926079, 'degree': 3, 'gamma': 6.143512644842968, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:44,194] Trial 176 finished with values: [0.9186412179994979, 0.03371795467281069] and parameters: {'C': 2.480676551727514, 'coef0': 4.70062327170197, 'degree': 3, 'gamma': 1.2719638682910315, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:44,517] Trial 177 finished with values: [0.6635444245239793, -0.012808461605859245] and parameters: {'C': 4.866923759646295, 'coef0': 5.762218149493524, 'degree': 2, 'gamma': 8.52180691393, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:45,216] Trial 178 finished with values: [0.7191511741001431, -0.010940801414779822] and parameters: {'C': 2.6200680675957186, 'degree': 10, 'gamma': 5.403563277187749, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:45,607] Trial 179 finished with values: [0.6864125924993155, 0.007977775771067175] and parameters: {'C': 7.528318185397283, 'coef0': 0.7555279816261595, 'degree': 9, 'gamma': 2.0237167035768784, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:46,024] Trial 180 finished with values: [0.6616988860815346, 0.006391010147365095] and parameters: {'C': 0.10494454342481872, 'coef0': 2.3419231773221783, 'degree': 9, 'gamma': 4.562122187849798, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:46,846] Trial 181 finished with values: [0.704695087057474, -0.005630360246485333] and parameters: {'C': 7.528318185397283, 'degree': 6, 'gamma': 9.243289410278518, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:47,466] Trial 182 finished with values: [0.612402112936009, -0.2183065094333424] and parameters: {'C': 4.996345646051818, 'degree': 6, 'gamma': 6.221114490339412, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:48,242] Trial 183 finished with values: [0.7748202735527353, -0.01410142100455769] and parameters: {'C': 7.528318185397283, 'degree': 6, 'gamma': 4.43017740432043, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:49,168] Trial 184 finished with values: [0.6558793037776548, -0.13416470512827838] and parameters: {'C': 7.984554287093118, 'degree': 8, 'gamma': 8.422337446790786, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:49,932] Trial 185 finished with values: [0.5512859970977901, -0.22869313424741633] and parameters: {'C': 8.483572584797336, 'degree': 3, 'gamma': 4.43017740432043, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:50,249] Trial 186 finished with values: [0.6687058093595942, -0.004981560803451246] and parameters: {'C': 4.835080145334154, 'coef0': 6.05315742624901, 'degree': 7, 'gamma': 8.125315669138603, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:50,695] Trial 187 finished with values: [0.5082745023355705, -0.17911073185142246] and parameters: {'C': 2.1432655928676976, 'degree': 2, 'gamma': 4.8709541998246495, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:51,273] Trial 188 finished with values: [0.6723257107621451, -0.10503499781509074] and parameters: {'C': 4.210325407172124, 'degree': 10, 'gamma': 5.403563277187749, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:52,172] Trial 189 finished with values: [1.2489222315432753, 0.508997763284421] and parameters: {'C': 7.528318185397283, 'degree': 7, 'gamma': 1.6830744649424811, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:52,966] Trial 190 finished with values: [0.6817438643090877, 0.0302218083225394] and parameters: {'C': 7.408557264582804, 'degree': 4, 'gamma': 6.221114490339412, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:53,311] Trial 191 finished with values: [0.6645873576515332, -0.005652850627293371] and parameters: {'C': 3.0288270710625356, 'coef0': 6.566218010977757, 'degree': 7, 'gamma': 6.342758134297629, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:21:53,950] Trial 192 finished with values: [0.8135199005670897, 0.0341204408117608] and parameters: {'C': 2.2557021449241383, 'degree': 9, 'gamma': 3.3233744812291652, 'kernel': 'rbf'}.
# [I 2023-08-06 17:21:54,416] Trial 193 finished with values: [0.6994254493248003, -0.052923059557555274] and parameters: {'C': 2.2557021449241383, 'degree': 4, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:55,221] Trial 194 finished with values: [0.6794292189036415, -0.07886908616088906] and parameters: {'C': 9.295662948074273, 'degree': 4, 'gamma': 1.6830744649424811, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:56,069] Trial 195 finished with values: [0.7022409997843603, -0.14426538336678352] and parameters: {'C': 9.028681720820531, 'degree': 2, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:56,508] Trial 196 finished with values: [1.125940661944432, 0.026455592319414967] and parameters: {'C': 2.796551956311084, 'coef0': 8.330543636229823, 'degree': 9, 'gamma': 3.044180673421067, 'kernel': 'poly'}.
# [I 2023-08-06 17:21:57,146] Trial 197 finished with values: [1.101099339347777, 0.293669750188589] and parameters: {'C': 4.122597480020839, 'degree': 9, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:57,802] Trial 198 finished with values: [0.6586634037830802, -0.0850774647353113] and parameters: {'C': 6.339482565955765, 'degree': 8, 'gamma': 6.012012255572937, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:58,256] Trial 199 finished with values: [0.7003914625841833, 0.0026067722419297334] and parameters: {'C': 2.1432655928676976, 'degree': 9, 'gamma': 4.227536725110943, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:59,085] Trial 200 finished with values: [1.387651077389653, 0.7065831967415441] and parameters: {'C': 7.22026446037536, 'degree': 9, 'gamma': 6.579144394084249, 'kernel': 'linear'}.
# [I 2023-08-06 17:21:59,750] Trial 201 finished with values: [0.5038136532385741, -0.1811892025283307] and parameters: {'C': 4.866923759646295, 'degree': 2, 'gamma': 0.6624561737856515, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:00,172] Trial 202 finished with values: [0.8603777860081773, 0.09150764943470302] and parameters: {'C': 1.7998428986581108, 'degree': 9, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:00,918] Trial 203 finished with values: [0.5276251535942816, -0.25442036365834475] and parameters: {'C': 6.0220026727620235, 'degree': 8, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:01,689] Trial 204 finished with values: [0.7506967846315027, 0.011597014580834286] and parameters: {'C': 9.028681720820531, 'degree': 2, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:02,506] Trial 205 finished with values: [0.9744748027459513, 0.2592473683563554] and parameters: {'C': 8.055607770026281, 'degree': 6, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:03,359] Trial 206 finished with values: [0.5946351252782963, -0.3619704682516035] and parameters: {'C': 9.170964322047395, 'degree': 6, 'gamma': 7.782127182069295, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:04,047] Trial 207 finished with values: [0.9511093204912291, 0.17022460696160246] and parameters: {'C': 7.984554287093118, 'degree': 9, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:04,729] Trial 208 finished with values: [0.7127854078044717, 0.03461593613357716] and parameters: {'C': 5.430950028231977, 'degree': 1, 'gamma': 3.4748581836487165, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:05,187] Trial 209 finished with values: [0.6927449177474153, -0.19446694398180864] and parameters: {'C': 1.6353155366295797, 'degree': 9, 'gamma': 4.43017740432043, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:05,405] Trial 210 finished with values: [0.7009044578971528, 0.12328601693965546] and parameters: {'C': 0.10494454342481872, 'degree': 1, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:06,063] Trial 211 finished with values: [0.5119230649463269, -0.3965438743424686] and parameters: {'C': 5.891862679866411, 'degree': 1, 'gamma': 8.672563594358866, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:06,887] Trial 212 finished with values: [0.9059870823329733, 0.1474537716917098] and parameters: {'C': 7.528318185397283, 'degree': 8, 'gamma': 3.4748581836487165, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:07,728] Trial 213 finished with values: [0.7702911454653879, -0.03354353761319351] and parameters: {'C': 8.483572584797336, 'degree': 9, 'gamma': 1.444042703471983, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:08,168] Trial 214 finished with values: [1.2773549815309446, -0.20418640877704886] and parameters: {'C': 7.408557264582804, 'coef0': 4.737178321289093, 'degree': 8, 'gamma': 5.028169341748529, 'kernel': 'poly'}.
# [I 2023-08-06 17:22:08,777] Trial 215 finished with values: [0.4902033634409914, -0.23246116375666753] and parameters: {'C': 4.835080145334154, 'degree': 6, 'gamma': 5.760061383659807, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:09,117] Trial 216 finished with values: [0.6690938139160573, -0.0035308254842750797] and parameters: {'C': 2.529374263268384, 'coef0': 0.5811943552485266, 'degree': 4, 'gamma': 6.221114490339412, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:22:09,872] Trial 217 finished with values: [0.8107970591295642, 0.05316576042278964] and parameters: {'C': 7.9451838348558175, 'degree': 8, 'gamma': 1.0716951169250413, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:10,680] Trial 218 finished with values: [0.524763779014993, -0.11337713581472064] and parameters: {'C': 7.9451838348558175, 'degree': 1, 'gamma': 5.403563277187749, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:11,501] Trial 219 finished with values: [0.6944654206473492, 0.05175135162360189] and parameters: {'C': 8.483572584797336, 'degree': 1, 'gamma': 4.359531446008861, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:12,396] Trial 220 finished with values: [0.5372818701361978, -0.1589820168433156] and parameters: {'C': 7.9451838348558175, 'degree': 8, 'gamma': 4.43017740432043, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:13,178] Trial 221 finished with values: [0.4179866654062181, -0.42966928878370747] and parameters: {'C': 7.408557264582804, 'degree': 4, 'gamma': 6.221114490339412, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:13,981] Trial 222 finished with values: [0.5808068096028776, -0.07112991770616728] and parameters: {'C': 8.483572584797336, 'degree': 10, 'gamma': 4.359531446008861, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:14,438] Trial 223 finished with values: [0.6448066464369019, -0.1177825457205669] and parameters: {'C': 2.1432655928676976, 'degree': 2, 'gamma': 9.981695481683698, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:15,247] Trial 224 finished with values: [0.9183128134771594, 0.17573117476659028] and parameters: {'C': 8.483572584797336, 'degree': 9, 'gamma': 6.858088253152906, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:15,615] Trial 225 finished with values: [0.5955405257359668, -0.0003259949340104207] and parameters: {'C': 0.10494454342481872, 'degree': 3, 'gamma': 4.562122187849798, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:16,441] Trial 226 finished with values: [0.7012837503473424, 0.10013884399753659] and parameters: {'C': 7.9451838348558175, 'degree': 6, 'gamma': 1.0716951169250413, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:16,798] Trial 227 finished with values: [0.9391369591645049, -0.013343461054432737] and parameters: {'C': 0.10494454342481872, 'coef0': 7.497073561271695, 'degree': 3, 'gamma': 4.783550978054576, 'kernel': 'poly'}.
# [I 2023-08-06 17:22:17,072] Trial 228 finished with values: [0.5000101678967276, -0.09776536654868273] and parameters: {'C': 0.40840908696559963, 'degree': 10, 'gamma': 5.403563277187749, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:17,871] Trial 229 finished with values: [0.45164514237457615, -0.3389971162936181] and parameters: {'C': 7.408557264582804, 'degree': 4, 'gamma': 6.221114490339412, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:18,134] Trial 230 finished with values: [1.6166564888113204, 0.3988353451558371] and parameters: {'C': 7.290497844991682, 'coef0': 0.6233888607861904, 'degree': 2, 'gamma': 4.359531446008861, 'kernel': 'poly'}.
# [I 2023-08-06 17:22:18,893] Trial 231 finished with values: [0.9524901043712943, 0.1436999268678364] and parameters: {'C': 7.408557264582804, 'degree': 4, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:19,494] Trial 232 finished with values: [0.6932046485997753, -0.00013920310188542118] and parameters: {'C': 0.037350502189183316, 'degree': 8, 'gamma': 4.359531446008861, 'kernel': 'rbf'}.
# [I 2023-08-06 17:22:20,325] Trial 233 finished with values: [0.6518256802744149, -0.17478211578629144] and parameters: {'C': 8.483572584797336, 'degree': 3, 'gamma': 7.563751322267558, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:21,055] Trial 234 finished with values: [0.7075304675423729, -0.007320656058841801] and parameters: {'C': 4.866923759646295, 'degree': 1, 'gamma': 8.52180691393, 'kernel': 'rbf'}.
# [I 2023-08-06 17:22:22,005] Trial 235 finished with values: [0.6382289124822281, -0.24422489723538887] and parameters: {'C': 8.483572584797336, 'degree': 10, 'gamma': 6.221114490339412, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:22,670] Trial 236 finished with values: [0.7689114572360954, 0.037815515772793185] and parameters: {'C': 8.483572584797336, 'degree': 2, 'gamma': 5.028169341748529, 'kernel': 'rbf'}.
# [I 2023-08-06 17:22:23,131] Trial 237 finished with values: [0.6269459062641923, -0.09822679803326684] and parameters: {'C': 2.480676551727514, 'degree': 6, 'gamma': 6.795512579544581, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:23,392] Trial 238 finished with values: [0.508916308300534, -0.21417070925982784] and parameters: {'C': 0.30819878848471216, 'degree': 9, 'gamma': 8.422337446790786, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:23,708] Trial 239 finished with values: [0.6436345795102275, -0.044660613484860945] and parameters: {'C': 0.7129676666563982, 'degree': 9, 'gamma': 4.406625747318254, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:24,107] Trial 240 finished with values: [0.686390572780781, 0.0035631348497582316] and parameters: {'C': 7.408557264582804, 'coef0': 4.213978733819187, 'degree': 4, 'gamma': 3.044180673421067, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:22:24,750] Trial 241 finished with values: [1.7944953887657449, -0.02505953264105565] and parameters: {'C': 7.528318185397283, 'degree': 4, 'gamma': 0.15175168626337207, 'kernel': 'rbf'}.
# [I 2023-08-06 17:22:25,412] Trial 242 finished with values: [0.5098473023275124, -0.2372220634906972] and parameters: {'C': 4.996345646051818, 'degree': 6, 'gamma': 6.221114490339412, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:26,590] Trial 243 finished with values: [0.9647449307206314, -0.045244148242952975] and parameters: {'C': 7.9451838348558175, 'coef0': 6.638374760394624, 'degree': 1, 'gamma': 2.6020038915210386, 'kernel': 'poly'}.
# [I 2023-08-06 17:22:27,519] Trial 244 finished with values: [0.5959453379257691, -0.13962941333658718] and parameters: {'C': 8.483572584797336, 'degree': 5, 'gamma': 5.028169341748529, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:28,413] Trial 245 finished with values: [0.8375116147184145, 0.15788508756943975] and parameters: {'C': 9.170964322047395, 'degree': 1, 'gamma': 8.422337446790786, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:28,766] Trial 246 finished with values: [0.6460485865913075, -0.0407649136200402] and parameters: {'C': 5.800287855403815, 'coef0': 7.106615177836465, 'degree': 4, 'gamma': 5.028169341748529, 'kernel': 'sigmoid'}.
# [I 2023-08-06 17:22:29,029] Trial 247 finished with values: [0.5001801815280856, -0.12962890880457645] and parameters: {'C': 0.40840908696559963, 'degree': 9, 'gamma': 5.403563277187749, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:29,887] Trial 248 finished with values: [1.1717028097758453, 0.3171799607061432] and parameters: {'C': 9.028681720820531, 'degree': 9, 'gamma': 9.714313336416213, 'kernel': 'linear'}.
# [I 2023-08-06 17:22:30,253] Trial 249 finished with values: [0.9585435538888719, 0.012081813700599797] and parameters: {'C': 9.028681720820531, 'coef0': 5.991605533657598, 'degree': 3, 'gamma': 6.143512644842968, 'kernel': 'poly'}.
